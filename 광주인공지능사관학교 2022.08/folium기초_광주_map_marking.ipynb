# %% [markdown]
# 구글크롤링 크롬드라이버검색

# %%
# 폴리움 불러오기, 버전확인
import folium
folium.__version__

# 오픈스트리트맵에 광주광역시청과구청을표시

# 맵을 표시할 중심점을 찍는다
map = folium.Map(location=[35.159841,126.851784], zoom_start=12 , max_width=200) # (위도,경도)

# 마커는 마킹만한다
folium.Marker(
    location=[35.159841,126.851784] , # [위도,경도]
    popup=folium.Popup('광주광역시 서구 내방로 111'), # 마커누르면나오는문구
    tooltip='광주광역시청', #마커에 커서올리면나오는문구
    icon=folium.Icon(color='red',icon='camera') # 마커 아이콘옵션, 색상/아이콘모양 
).add_to(map)

folium.Marker(
    location=[ 35.14614999401774,126.92309512856308] ,
    popup=folium.Popup('광주광역시 동구 서남로 1'),
    tooltip='광주광역시 동구청',
    icon=folium.Icon(color='crimson',icon='camera')
).add_to(map)

folium.Marker(
    location=[35.152089096162236,126.88985826388209] ,
    popup=folium.Popup('광주광역시 서구 농성동 경열로 33'),
    tooltip='광주 서구청',
    icon=folium.Icon(color='green',icon='camera')
).add_to(map)

folium.Marker(
    location=[35.17410046937537,126.91215706204946] ,
    popup=folium.Popup('광주광역시 북구 우치로 77'),
    tooltip='광주 북구청',
    icon=folium.Icon(color='pink',icon='camera')
).add_to(map)

folium.Marker(
    location=[35.13290098068543,126.90257332634087] ,
    popup=folium.Popup('광주광역시 남구 봉선로 1'),
    tooltip='광주 남구청',
    icon=folium.Icon(color='black',icon='camera')
).add_to(map)

folium.Marker(
    location=[35.13955198869462,126.79380680502933] ,
    popup=folium.Popup('광주광역시 광산구 광산로29번길 15'),
    tooltip='광주 광산구청'
).add_to(map)
map

# 저장-다운로드
map.save("광주.html")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:22: UserWarning: color argument of Icon should be one of: {'lightred', 'darkred', 'lightgreen', 'darkblue', 'darkpurple', 'white', 'orange', 'cadetblue', 'darkgreen', 'gray', 'lightgray', 'beige', 'black', 'purple', 'red', 'green', 'lightblue', 'blue', 'pink'}.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_747b717627b4aa2b263c69a9bdfe4356 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_747b717627b4aa2b263c69a9bdfe4356&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_747b717627b4aa2b263c69a9bdfe4356 = L.map(
#                 &quot;map_747b717627b4aa2b263c69a9bdfe4356&quot;,
#                 {
#                     center: [35.159841, 126.851784],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     maxWidth: 200,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f6a475fd4f4c6f90bdf84119cc4d7071 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_747b717627b4aa2b263c69a9bdfe4356);
#
#
#             var marker_f66882e276f51c3c9bea10963cdc80de = L.marker(
#                 [35.159841, 126.851784],
#                 {}
#             ).addTo(map_747b717627b4aa2b263c69a9bdfe4356);
#
#
#             var icon_5bce3cd339c4d91ecfbd9f41e5754b93 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;camera&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f66882e276f51c3c9bea10963cdc80de.setIcon(icon_5bce3cd339c4d91ecfbd9f41e5754b93);
#
#
#         var popup_aef4cf86be491f75492e2ae1365be31a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_418ab5d8634181667052c371143e8671 = $(`&lt;div id=&quot;html_418ab5d8634181667052c371143e8671&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;광주광역시 서구 내방로 111&lt;/div&gt;`)[0];
#             popup_aef4cf86be491f75492e2ae1365be31a.setContent(html_418ab5d8634181667052c371143e8671);
#
#
#         marker_f66882e276f51c3c9bea10963cdc80de.bindPopup(popup_aef4cf86be491f75492e2ae1365be31a)
#         ;
#
#
#
#
#             marker_f66882e276f51c3c9bea10963cdc80de.bindTooltip(
#                 `&lt;div&gt;
#                      광주광역시청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a0ab23e7855e2aee0e8abbcc96246062 = L.marker(
#                 [35.14614999401774, 126.92309512856308],
#                 {}
#             ).addTo(map_747b717627b4aa2b263c69a9bdfe4356);
#
#
#             var icon_55570f7192c22c5c75191762bf6ff594 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;camera&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;crimson&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a0ab23e7855e2aee0e8abbcc96246062.setIcon(icon_55570f7192c22c5c75191762bf6ff594);
#
#
#         var popup_7be3487c17a8243806a913201c43da64 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_035de7b3cd3e8859c2f73f73342e832b = $(`&lt;div id=&quot;html_035de7b3cd3e8859c2f73f73342e832b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;광주광역시 동구 서남로 1&lt;/div&gt;`)[0];
#             popup_7be3487c17a8243806a913201c43da64.setContent(html_035de7b3cd3e8859c2f73f73342e832b);
#
#
#         marker_a0ab23e7855e2aee0e8abbcc96246062.bindPopup(popup_7be3487c17a8243806a913201c43da64)
#         ;
#
#
#
#
#             marker_a0ab23e7855e2aee0e8abbcc96246062.bindTooltip(
#                 `&lt;div&gt;
#                      광주광역시 동구청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5e08ad46e195dda955101c348dbb544b = L.marker(
#                 [35.152089096162236, 126.88985826388209],
#                 {}
#             ).addTo(map_747b717627b4aa2b263c69a9bdfe4356);
#
#
#             var icon_1b020df2bb93208ba6b406b58b93ab31 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;camera&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5e08ad46e195dda955101c348dbb544b.setIcon(icon_1b020df2bb93208ba6b406b58b93ab31);
#
#
#         var popup_34a86d26d85bb5ec03876a59ad6ffab5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_4225edfa4cb3590488047009321c216a = $(`&lt;div id=&quot;html_4225edfa4cb3590488047009321c216a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;광주광역시 서구 농성동 경열로 33&lt;/div&gt;`)[0];
#             popup_34a86d26d85bb5ec03876a59ad6ffab5.setContent(html_4225edfa4cb3590488047009321c216a);
#
#
#         marker_5e08ad46e195dda955101c348dbb544b.bindPopup(popup_34a86d26d85bb5ec03876a59ad6ffab5)
#         ;
#
#
#
#
#             marker_5e08ad46e195dda955101c348dbb544b.bindTooltip(
#                 `
