# %%
# 1. 리스트

ui = '''########### 자동차 정보 프로그램 ###########                
1. 자동차 정보 입력
2. 저장된 목록 보기
3. 각 자동차의 구매 가격 조회
4. 옵션이 있는 자동차 정보 조회
5. 빠른 자동차와 느린 자동차의 속도 차 조회
6. 프로그램 이용 종료
############################################
1~6 중 하나를 입력하세요:'''

#전역변수            
자동차_리스트 = []  
리스트최고속도 = 0
리스트최저속도 = 1000

while True :
    
    n = int(input(ui))

    #1. 자동차 정보 입력
    if n == 1 :
        print('<자동차 정보입력>') #안내문
        이름 = input('이름:')
        엔진가격 = int(input('엔진가격:'))
        타이어가격 = int(input('타이어가격:'))
        옵션유무 = input('옵션유무:')
        옵션이름 = input('옵션이름:')
        최고속도 = int(input('최고속도:'))
        리스트최고속도 = 리스트최고속도 if 리스트최고속도 > 최고속도 else 최고속도
        리스트최저속도 = 리스트최저속도 if 리스트최저속도 < 최고속도 else 최고속도
        구매가격 = 엔진가격 + 타이어가격
        자동차_정보 = [이름, 엔진가격, 타이어가격, 옵션유무, 옵션이름, 최고속도, 구매가격]
        자동차_리스트.append(자동차_정보)

    #2. 저장된 목록 보기
    elif n == 2:
        for i in range(len(자동차_리스트)):
            print( f'{i+1}번 차량')
            print( '-'*30)              #안내선
            print(f'''자동차 이름:{자동차_리스트[i][0]}
자동차 엔진가격:{자동차_리스트[i][1]}
자동차 타이어가격:{자동차_리스트[i][2]}
자동차 옵션유무:{자동차_리스트[i][3]}
자동차 옵션이름:{자동차_리스트[i][4]}
자동차 최고속도:{자동차_리스트[i][5]}
자동차 구매가격:{자동차_리스트[i][6]}''')
            print( '-'*30)              #안내선

    # 3. 각 자동차의 구매 가격 조회
    elif n == 3 :
        for i in range(len(자동차_리스트)):
            print( f'{i+1}번 차량')
            print( '-'*30)              #안내선
            print(f'''자동차 이름:{자동차_리스트[i][0]}
자동차 구매가격:{자동차_리스트[i][6]}''')
            print( '-'*30)              #안내선

    # 4. 옵션이 있는 자동차 정보 조회
    elif n == 4 :
        for i in range(len(자동차_리스트)):
          if 자동차_리스트[i][3] == '있음' :
            print( f'{i+1}번 차량')
            print( '-'*30)              #안내선
            print(f'''자동차 이름:{자동차_리스트[i][0]}
자동차 엔진가격:{자동차_리스트[i][1]}
자동차 타이어가격:{자동차_리스트[i][2]}
자동차 옵션유무:{자동차_리스트[i][3]}
자동차 옵션이름:{자동차_리스트[i][4]}
자동차 최고속도:{자동차_리스트[i][5]}
자동차 구매가격:{자동차_리스트[i][6]}''')
            print( '-'*30)              #안내선

    # 5. 빠른 자동차와 느린 자동차의 속도 차 조회
    elif n == 5 : 
        print(f'리스트 안의 속도차 {리스트최고속도 - 리스트최저속도}')

    # 6.  프로그램 이용 종료
    elif n == 6 :
        print('프로그램이 종료됩니다.')
        break
    else:
        print('기능은 1~6까지만 있습니다.')

# %%
#1. 리스트 안보고

# elif 를 전부 if로 씀 
# else문 빼먹음 
# ui 인풋에 int()를 걸지 않음 
# 조건문 조건 뒤에 : 콜론 다수 빼먹음
# 특정조회에서 몇번차량인지 프린트 안함 no error
# 연속된 프린트문에 ''''''을 하지 않음 no error
#  if   자동차_리스트[i][3] == '있음' :      있음에 ' ' 안침 



ui= '''#자동차 정보 프로그램#
1, 자동차 정보 입력
2. 저장된 목록 보기
3. 각 자동차의 구매 가격 조회
4. 옵션이 있는 자동차 정보 조회
5. 빠른 자동차와 느린 자동차의 속도차 조회
6. 프로그램 이용 종료
#############################
1~6 중 하나를 입력하세요:'''

#전역변수

자동차_정보=[]         
자동차_리스트=[]
리스트최고속도=0
리스트최저속도=1000
while True:
    
    n = int(input(ui))

    # 1, 자동차 정보 입력
    if n == 1 :
        print('자동차 정보를 입력하세요.')
        print('-'*50)
        이름 = input('이름:')
        엔진가격 = int(input('엔진가격:'))
        타이어가격 = int(input('타이어가격:'))
        옵션유무 = input('옵션유무:')
        옵션이름 = input('옵션이름:')
        최고속도 = int(input('최고속도:'))
        리스트최고속도 = 리스트최고속도 if 리스트최고속도 > 최고속도 else 최고속도
        리스트최저속도 = 리스트최저속도 if 리스트최저속도 < 최고속도 else 최고속도
        구매가격 = 엔진가격 + 타이어가격
        자동차_정보 = [이름, 엔진가격, 타이어가격, 옵션유무, 옵션이름, 최고속도, 구매가격]
        자동차_리스트.append(자동차_정보)
        print('-'*50)

    #2. 저장된 목록 보기
    elif n == 2 :
        print('저장된 목록입니다.')
        print('-'*50)
        for i in range(len(자동차_리스트)):
            print(f'이름 : {자동차_리스트[i][0]}')
            print(f'엔진가격 : {자동차_리스트[i][1]}')
            print(f'타이어가격 : {자동차_리스트[i][2]}')
            print(f'옵션유무 : {자동차_리스트[i][3]}')
            print(f'옵션이름 : {자동차_리스트[i][4]}')
            print(f'최고속도 : {자동차_리스트[i][5]}')
            print(f'구매가격 : {자동차_리스트[i][6]}')
            print('-'*50)

    #3. 각 자동차의 구매 가격 조회
    elif n == 3 :
        print('각 자동차의 구매 가격입니다')
        print('-'*50)
        for i in range(len(자동차_리스트)):
            print(f'이름 : {자동차_리스트[i][0]}')
            print(f'구매가격 : {자동차_리스트[i][6]}')
            print('-'*50)

    # 4. 옵션이 있는 자동차 정보 조회
    elif n == 4 :
        print('옵션이 있는 자동차의 정보입니다.')
        print('-'*50)
        for i in range(len(자동차_리스트)):
            if   자동차_리스트[i][3] == '있음' : 
                print(f'이름 : {자동차_리스트[i][0]}')
                print(f'엔진가격 : {자동차_리스트[i][1]}')
                print(f'타이어가격 : {자동차_리스트[i][2]}')
                print(f'옵션유무 : {자동차_리스트[i][3]}')
                print(f'옵션이름 : {자동차_리스트[i][4]}')
                print(f'최고속도 : {자동차_리스트[i][5]}')
                print(f'구매가격 : {자동차_리스트[i][6]}')
                print('-'*50)

    # 5. 빠른 자동차와 느린 자동차의 속도차 조회
    elif n == 5 :
        print('빠른 자동차와 느린 자동차의 속도차입니다.')
        print('-'*50)
        print( 리스트최고속도 - 리스트최저속도 )
        print('-'*50)

    # 6. 프로그램이용종료
    elif n == 6 :
        print('프로그램 이용을 종료합니다.')
        break
    else :
        print('1~6을 입력하지 않았습니다')

# %%
# 1. 리스트 안보고 두번째

#리스트최고최저속도 숫자를 입력 안하고 []함
#지역 인풋에 int( ) 안함

ui = '''##자동차정보프로그램##
1.자동차정보입력
2.저장목록보기
3.각자동차구매가격조회
4.옵션있는차조회
5. 속도차
6.프로그램종료
####
1~6 숫자를 입력하세요:'''

자동차_리스트=[]
리스트최고속도=0
리스트최저속도=1000

while True:
    n=int(input(ui))
    
    if n==1:
        print('자동차정보를입력하세요')
        print('-'*50)
        이름=input('이름:')
        엔진가격=int(input('엔진가격:'))
        타이어가격=int(input('타이어가격:'))
        옵션유무=input('옵션유무:')
        옵션이름=input('옵션이름:')
        최고속도=int(input('최고속도:'))
        리스트최고속도=리스트최고속도 if 리스트최고속도>최고속도 else 최고속도
        리스트최저속도=리스트최저속도 if 리스트최저속도<최고속도 else 최고속도
        구매가격=엔진가격+타이어가격
        자동차_정보=[이름,엔진가격,타이어가격,옵션유무,옵션이름,최고속도,구매가격]
        자동차_리스트.append(자동차_정보)
        print('-'*50)

    elif n==2:  
        print('저장목록')
        print('-'*50)  
        for i in range(len(자동차_리스트)):
            print(f'''{i+1}번 자동차:
이름: {자동차_리스트[i][0]}
엔진가격: {자동차_리스트[i][1]}
타이어가격: {자동차_리스트[i][2]}
옵션유무: {자동차_리스트[i][3]}
옵션이름: {자동차_리스트[i][4]}
최고속도: {자동차_리스트[i][5]}
구매가격: {자동차_리스트[i][6]}''')
            print('-'*50) 
            
    elif n==3 :
        print('각 자동차 구매가격')           
        print('-'*50)  
        for i in range(len(자동차_리스트)):
            print(f'''{i+1}번 자동차:
이름: {자동차_리스트[i][0]}
구매가격: {자동차_리스트[i][6]}''')
            print('-'*50) 

    elif n==4:  
        print('옵션있는자동차정보')
        print('-'*50)  
        for i in range(len(자동차_리스트)):
            if '있음' == 자동차_리스트[i][3]:
                print(f'''{i+1}번 자동차:
이름: {자동차_리스트[i][0]}
엔진가격: {자동차_리스트[i][1]}
타이어가격: {자동차_리스트[i][2]}
옵션유무: {자동차_리스트[i][3]}
옵션이름: {자동차_리스트[i][4]}
최고속도: {자동차_리스트[i][5]}
구매가격: {자동차_리스트[i][6]}''')
            print('-'*50) 
            
    elif n==5:
        print('속도차')
        print('-'*50)  
        print('빠른자동차와느린자동차의속도차는:', 리스트최고속도-리스트최저속도,'입니다')
        print('-'*50) 
    elif n==6:
        print('프로그램을종료합니다')    
        break
    else:
        print('기능은 1~6뿐입니다')

# %%
# 리스트 안보고 세번째

# f''' '''      f안붙임
#4번 망

ui = '''########### 자동차 정보 프로그램 ###########              
1. 자동차 정보 입력
2. 저장된 목록 보기
3. 각 자동차의 구매 가격 조회
4. 옵션이 있는 자동차 정보 조회
5. 빠른 자동차와 느린 자동차의 속도 차 조회
6. 프로그램 이용 종료
############################################
1~6 중 하나를 입력하세요:'''

자동차_리스트=[]
리스트최고속도=0
리스트최저속도=1000

while True:
    n =int(input(ui))

    if n==1:
        print('자동차정보입력')
        print('-'*60)
        이름=input('이름:')
        엔진가격=int(input('엔진가격:'))
        타이어가격=int(input('타이어가격:'))
        옵션유무=input('옵션유무:')
        옵션이름=input('옵션이름:')
        최고속도=int(input('최고속도:'))
        리스트최고속도=리스트최고속도 if 리스트최고속도>최고속도 else 최고속도
        리스트최저속도=리스트최저속도 if 리스트최저속도<최고속도 else 최고속도
        구매가격=엔진가격+타이어가격
        자동차_정보=[이름,엔진가격, 타이어가격, 옵션유무, 옵션이름, 최고속도, 구매가격]
        자동차_리스트.append(자동차_정보)
        print('-'*60)
    elif n==2 : 
        print('자동차목록')
        print('-'*60)
        for i in range(len(자동차_리스트)):
            print(f'''{i+1}번 자동차
이름 : {이름}        
엔진가격 : {엔진가격}
타이어가격 : {타이어가격}
옵션유무 : {옵션유무}
옵션이름 : {옵션이름}
최고속도 : {최고속도}
구매가격 : {구매가격}''')
            print('-'*60)
    elif n==3 :
        print('각자동차가격')
        print('-'*60)
        for i in range(len(자동차_리스트)):
            print(f'''{i+1}번 자동차
이름 : {이름}        
구매가격 : {구매가격}''')
            print('-'*60)
    elif n==4 :
        print('옵션있는자동차정보')
        print('-'*60)
        for i in range(len(자동차_리스트)):
            if 자동차_리스트[i][3] == '있음':
                print(f'''{i+1}번 자동차
이름 : {이름}        
엔진가격 : {엔진가격}
타이어가격 : {타이어가격}
옵션유무 : {옵션유무}
옵션이름 : {옵션이름} #####
최고속도 : {최고속도}
구매가격 : {구매가격}''')
                print('-'*60)
    elif n==5 :
        print('속도차')
        print('-'*60)
        print(f'빠차와늦차의속도차는 {리스트최고속도-리스트최저속도}입니다.')
        print('-'*60)
    else:
        if n==6:
            print('프로그램종료')    
            break

# %%
#리스트안보고 4번째 (final)
#엔진가격+구매가격이라고 입력함

ui = '''########### 자동차 정보 프로그램 ###########               
1. 자동차 정보 입력
2. 저장된 목록 보기
3. 각 자동차의 구매 가격 조회
4. 옵션이 있는 자동차 정보 조회
5. 빠른 자동차와 느린 자동차의 속도 차 조회
6. 프로그램 이용 종료
############################################
1~6 중 하나를 입력하세요:'''

자동차_리스트=[]
리스트최고속도=0
리스트최저속도=1000

while True:
    n=int(input(ui))
    if n==1:
        print('자동차정보입력')
        print('-'*70)
        이름=input('이름:')
        엔진가격=int(input('엔진가격:'))
        타이어가격=int(input('타이어가격:'))
        옵션유무=input('옵션유무:')
        옵션이름=input('옵션이름:')
        최고속도=int(input('최고속도:'))
        구매가격=엔진가격+타이어가격
        리스트최고속도=리스트최고속도 if 리스트최고속도 > 최고속도 else 최고속도
        리스트최저속도=리스트최저속도 if 리스트최저속도 > 최고속도 else 최저속도
        자동차_정보=[이름,엔진가격,타이어가격,옵션유무,옵션이름,최고속도,구매가격]
        자동차_리스트.append(자동차_정보)
        print('-'*70)
    elif  n==2:
        print('목록')
        print('-'*70)
        for i in range(len(자동차_리스트)):
            print(f'''{i+1}번째 자동차
이름 : {자동차_리스트[i][0]}
엔진 : {자동차_리스트[i][1]}
타이어 : {자동차_리스트[i][2]}
옵션우무 : {자동차_리스트[i][3]}
옵션이름 : {자동차_리스트[i][4]}
맥스스피드 : {자동차_리스트[i][5]}
구매가 : {자동차_리스트[i][6]}''')
            print('-'*70)
    elif  n==3:
        print('구매가')
        print('-'*70)
        for i in range(len(자동차_리스트)):
            print(f'''{i+1}번째 자동차
이름 : {자동차_리스트[i][0]}
구매가 : {자동차_리스트[i][6]}''')
            print('-'*70)
    elif  n==4:
        print('옵션있는차')
        print('-'*70)
        for i in range(len(자동차_리스트)):
            if '있음' == 자동차_리스트[i][3] :
                print(f'''{i+1}번째 자동차
이름 : {자동차_리스트[i][0]}
엔진 : {자동차_리스트[i][1]}
타이어 : {자동차_리스트[i][2]}
옵션우무 : {자동차_리스트[i][3]}
옵션이름 : {자동차_리스트[i][4]}
맥스스피드 : {자동차_리스트[i][5]}
구매가 : {자동차_리스트[i][6]}''')
                print('-'*70)
    elif  n==5:
        print('속도차')
        print('-'*70)
        print(f'속도차는 {리스트최고속도-리스트최저속도} 입니다.')
        print('-'*70)
    elif  n==6:
        print('프로그램종료')
        break
    else :
        print('1~6을입력하세요')

# %%
# 딕셔너리

# %%
#딕셔너리화 정리

ui = '''########### 자동차 정보 프로그램 ###########               
1. 자동차 정보 입력
2. 저장된 목록 보기
3. 각 자동차의 구매 가격 조회
4. 옵션이 있는 자동차 정보 조회
5. 빠른 자동차와 느린 자동차의 속도 차 조회
6. 프로그램 이용 종료
############################################
1~6 중 하나를 입력하세요:'''

자동차_리스트=[]
리스트최고속도=0
리스트최저속도=1000
while True: 
  n=int(input(ui))
  #1. 자동차 정보 입력
  if n==1:
    print("<자동차 정보입력>")
    이름=input("이름:")
    엔진가격=int(input("엔진가격:"))
    타이어가격=int(input("타이어가격:"))
    옵션유무=input("옵션유무:")
    옵션이름=input("옵션이름:")
    최고속도=int(input("최고속도:"))
    리스트최고속도= 리스트최고속도 if 리스트최고속도>최고속도 else 최고속도
    리스트최저속도= 리스트최저속도 if 리스트최저속도<최고속도 else 최고속도
    구매가격=엔진가격+타이어가격
    자동차_정보={'이름':이름,'엔진가격':엔진가격,'타이어가격':타이어가격,'옵션유무':옵션유무,
            '옵션이름':옵션이름,'최고속도':최고속도,'구매가격':구매가격}
    자동차_리스트.append(자동차_정보)
    input()
  #2. 저장된 목록 보기
  elif n==2:
    for i in range(len(자동차_리스트)):
      print(f"{i+1}번 차량")
      print("-"*30)
      print(f'''자동차 이름:{자동차_리스트[i]['이름']}
자동차 엔진가격:{자동차_리스트[i]['엔진가격']}
자동차 타이어가격:{자동차_리스트[i]['타이어가격']}
자동차 옵션유무:{자동차_리스트[i]['옵션유무']}
자동차 옵션이름:{자동차_리스트[i]['옵션이름']}
자동차 최고속도:{자동차_리스트[i]['최고속도']}
자동차 구매가격:{자동차_리스트[i]['구매가격']}''')
      print("-"*30)
    input()
  #3. 각 자동차의 구매 가격 조회
  elif n==3:
    for i in range(len(자동차_리스트)):
      print(f"{i+1}번 차량")
      print("-"*30)
      print(f'''자동차 이름:{자동차_리스트[i]['이름']}
자동차 구매가격:{자동차_리스트[i]['구매가격']}''')
      print("-"*30)
    input()
  #4. 옵션이 있는 자동차 정보 조회
  elif n==4:
    for i in range(len(자동차_리스트)):
      if 자동차_리스트[i]['옵션유무']=='있음':
        print(f"{i+1}번 차량")
        print("-"*30)
        print(f'''자동차 이름:{자동차_리스트[i]['이름']}
자동차 엔진가격:{자동차_리스트[i]['엔진가격']}
자동차 타이어가격:{자동차_리스트[i]['타이어가격']}
자동차 옵션유무:{자동차_리스트[i]['옵션유무']}
자동차 옵션이름:{자동차_리스트[i]['옵션이름']}
자동차 최고속도:{자동차_리스트[i]['최고속도']}
자동차 구매가격:{자동차_리스트[i]['구매가격']}''')
        print("-"*30)
    input()
  #5. 빠른 자동차와 느린 자동차의 속도 차 조회
  elif n==5:
    print(f'리스트 안의 속도차:{리스트최고속도-리스트최저속도}')
  #6. 프로그램 이용 종료
  elif n==6:
    print("프로그램이 종료됩니다.")
    break
  else:
    print("기능은 1~6까지만 있습니다.")

# %%
#딕셔너리 안보고 치기 1

# %%
# 지역인풋에 인트 안걸었음
# 3번 망 2차원경로설정
# 자동차_정보 [] 에 구매가격 안넣음
# 구매가격 이차원처리 안함



ui = '''########### 자동차 정보 프로그램 ###########             
1. 자동차 정보 입력
2. 저장된 목록 보기
3. 각 자동차의 구매 가격 조회
4. 옵션이 있는 자동차 정보 조회
5. 빠른 자동차와 느린 자동차의 속도 차 조회
6. 프로그램 이용 종료
############################################
1~6 중 하나를 입력하세요:'''

자동차_리스트=[]
리스트최고속도=0
리스트최저속도=1000

while True:

    n=int(input(ui))

    if n==1:
        print('자동차정보를입력해')
        print('-'*80)
        이름=input('이름:')
        엔진가격=int(input('엔진가:'))
        타이어가격=int(input('타이어가'))
        옵션유무=input('옵션유무')
        옵션이름=input('옵이름')
        최고속도=int(input('맥스스피드'))
        구매가격=엔진가격+타이어가격
        리스트최고속도=리스트최고속도 if 리스트최고속도>최고속도 else 최고속도
        리스트최저속도=리스트최저속도 if 리스트최저속도<최고속도 else 최고속도
        자동차_정보 = { '이름':이름, '엔진가격':엔진가격,'타이어가격':타이어가격, '옵션유무':옵션유무, '옵션이름':옵션이름, '최고속도':최고속도,
                       '구매가격':구매가격}
        자동차_리스트.append(자동차_정보)
        print('-'*80)
    elif n==2:    
        print('목록')
        print('-'*80)
        for i in range(len(자동차_리스트)):
            print(f'''{i+1}번 자동차        
이름 : {자동차_리스트[i]['이름']}
엔진가격 : {자동차_리스트[i]['엔진가격']}
타이어가격 : {자동차_리스트[i]['타이어가격']}
옵션유무 : {자동차_리스트[i]['옵션유무']}
옵션이름 : {자동차_리스트[i]['옵션이름']}
최고속도 : {자동차_리스트[i]['최고속도']}
구매가격 : {자동차_리스트[i]['구매가격']}''')
            print('-'*80)
    elif n==3:
        print('구매가')
        print('-'*80)
        for i in range(len(자동차_리스트)):
            print(f'''{i+1}번 자동차       
이름 : {자동차_리스트[i]['이름']}             
구매가격 : {자동차_리스트[i]['구매가격']}''')
            print('-'*80)
    elif n==4:
        print('옵션있는차')
        print('-'*80)
        for i in range(len(자동차_리스트)):
            if 자동차_리스트[i]['옵션유무'] == '있음':
                print(f'''{i+1}번 자동차        
이름 : {자동차_리스트[i]['이름']}
엔진가격 : {자동차_리스트[i]['엔진가격']}
타이어가격 : {자동차_리스트[i]['타이어가격']}
옵션유무 : {자동차_리스트[i]['옵션유무']}
옵션이름 : {자동차_리스트[i]['옵션이름']}
최고속도 : {자동차_리스트[i]['최고속도']}
구매가격 : {자동차_리스트[i]['구매가격']}''')
                print('-'*80)
    elif n==5:
        print('속도차')
        print('-'*80)
        print(f'빠차와늦차의속도차는 {리스트최고속도-리스트최저속도} 입니다')
        print('-'*80)
    elif n==6: 
        print('플그램종료')
        break
    else:
        print('기능은1~6만있음')

# %%
# 딕셔너리안보고치기 2

# %%
# 지역인풋에 int(안함)
# 인풋 안내문 망

ui = '''########### 자동차 정보 프로그램 ###########               
1. 자동차 정보 입력
2. 저장된 목록 보기
3. 각 자동차의 구매 가격 조회
4. 옵션이 있는 자동차 정보 조회
5. 빠른 자동차와 느린 자동차의 속도 차 조회
6. 프로그램 이용 종료
############################################
1~6 중 하나를 입력하세요:'''

자동차_리스트=[]
리스트최고속도=0
리스트최저속도=1000

while True:
    n=int(input(ui))
    if n==1:
        print('자동차정보를입력해')
        print('-'*85)
        이름=input('이름:')
        엔진가격=int(input('엔진가격:'))
        타이어가격=int(input('타이어가격:'))
        옵션유무=input('옵션유무:')
        옵션이름=input('옵션이름:')
        최고속도=int(input('맥스스피드:'))
        구매가격= 엔진가격 + 타이어가격
        리스트최고속도=리스트최고속도 if 리스트최고속도 > 최고속도 else 최고속도
        리스트최저속도=리스트최저속도 if 리스트최저속도 < 최고속도 else 최고속도
        자동차_정보={ '이름':이름,'엔진가격':엔진가격,'타이어가격':타이어가격,'옵션유무':옵션유무,'옵션이름':옵션이름,'최고속도':최고속도
                     ,'구매가격':구매가격}
        자동차_리스트.append(자동차_정보)  
        print('-'*85)
    elif n==2:
        print('목록')
        print('-'*85)
        for i in range(len(자동차_리스트)):
            print(f'''{i+1}번 자동차
이름 : {자동차_리스트[i]['이름']}
엔진가격 : {자동차_리스트[i]['엔진가격']}
타이어가격 : {자동차_리스트[i]['타이어가격']}
옵션유무 : {자동차_리스트[i]['옵션유무']}
옵션이름 : {자동차_리스트[i]['옵션이름']}
최고속도 : {자동차_리스트[i]['최고속도']}
구매가격 : {자동차_리스트[i]['구매가격']}''')
            print('-'*85)
    elif n==3:
        print('구매가')
        print('-'*85)
        for i in range(len(자동차_리스트)):
            print(f'''{i+1}번 자동차
이름 : {자동차_리스트[i]['이름']}
구매가격 : {자동차_리스트[i]['구매가격']}''')
            print('-'*85)
    elif n==4:
        print('목록')
        print('-'*85)
        for i in range(len(자동차_리스트)):
            if 자동차_리스트[i]['옵션유무'] == '있음':
                print(f'''{i+1}번 자동차
이름 : {자동차_리스트[i]['이름']}
엔진가격 : {자동차_리스트[i]['엔진가격']}
타이어가격 : {자동차_리스트[i]['타이어가격']}
옵션유무 : {자동차_리스트[i]['옵션유무']}
옵션이름 : {자동차_리스트[i]['옵션이름']}
최고속도 : {자동차_리스트[i]['최고속도']}
구매가격 : {자동차_리스트[i]['구매가격']}''')
                print('-'*85)
    elif n==5:
        print('속도차')
        print('-'*85)
        print(f'빠차와 늦차의 속도차는 {리스트최고속도-리스트최저속도}압나다.')
        print('-'*85)
    elif n==6:
        print('프로그램종료')
        break
    else:
        print('1~6숫자를입력해')

# %%
# 딕셔너리안보고치기 3

# %%
# 키값에 인덱스를 넣어버림
# 오타 다수

ui = '''########### 자동차 정보 프로그램 ###########               
1. 자동차 정보 입력
2. 저장된 목록 보기
3. 각 자동차의 구매 가격 조회
4. 옵션이 있는 자동차 정보 조회
5. 빠른 자동차와 느린 자동차의 속도 차 조회
6. 프로그램 이용 종료
############################################
1~6 중 하나를 입력하세요:'''

자동차_리스트=[]
리스트최고속도=0
리스트최저속도=10000

while True:
    n=int(input(ui))
    if n==1:
        print('자동차정보')
        print('-'*90)
        이름=input('이름:')
        엔진가격=int(input('엔진가:'))
        타이어가격=int(input('타이어가격:'))
        옵션유무=input('옵션유무:')
        옵션이름=input('옵션이름:')
        최고속도=int(input('최고속도:'))
        구매가격= 엔진가격 + 타이어가격
        리스트최고속도=리스트최고속도 if 리스트최고속도 > 최고속도 else 최고속도    
        리스트최저속도=리스트최저속도 if 리스트최저속도 < 최고속도 else 최고속도
        자동차_정보={'이름':이름, '엔진가격':엔진가격, '타이어가격':타이어가격, '옵션유무': 옵션유무,'옵션이름':옵션이름,'최고속도':최고속도,    '구매가격':구매가격}
        자동차_리스트.append(자동차_정보)
        print('-'*90)    
    elif n==2:     
        print('자동차목록')
        print('-'*90)
        for i in range(len(자동차_리스트)):
            print(f'''{i+1}번 자동차
이름 : {자동차_리스트[i]['이름']}
엔진가격 : {자동차_리스트[i]['엔진가격']}
타이어가격 : {자동차_리스트[i]['타이어가격']}
옵션유무 : {자동차_리스트[i]['옵션유무']}
옵션이름 : {자동차_리스트[i]['옵션이름']}
최고속도 : {자동차_리스트[i]['최고속도']}
구매가격 : {자동차_리스트[i]['구매가격']}''')        
            print('-'*90)    
    elif n==3:
        print('자동차구매가')
        print('-'*90)
        for i in range(len(자동차_리스트)):
            print(f'''{i+1}번 자동차
이름 : {자동차_리스트[i]['이름']}
구매가격 : {자동차_리스트[i]['구매가격']}''')          
            print('-'*90)
    elif n==4:
        print('옵션있는차')
        print('-'*90)
        for i in range(len(자동차_리스트)):
            if 자동차_리스트[i]['옵션유무'] == '있음':
                print(f'''{i+1}번 자동차
이름 : {자동차_리스트[i]['이름']}
엔진가격 : {자동차_리스트[i]['엔진가격']}
타이어가격 : {자동차_리스트[i]['타이어가격']}
옵션유무 : {자동차_리스트[i]['옵션유무']}
옵션이름 : {자동차_리스트[i]['옵션이름']}
최고속도 : {자동차_리스트[i]['최고속도']}
구매가격 : {자동차_리스트[i]['구매가격']}''')               
                print('-'*90)
    elif n==5:
        print('속도차')
        print('-'*90)
        print(f'빠차와늦차의속도차는 {리스트최고속도-리스트최저속도} 입니다.')        
        print('-'*90)
    elif n==6:
        print('플그램종료')
        print('-'*90)
        break
    else:            
        print('1~6을 입력해')  
        print('-'*90)

# %%
# 딕셔너리 안보고 치기4

# %%
# < 부호
# ))

ui = '''########### 자동차 정보 프로그램 ###########
1. 자동차 정보 입력
2. 저장된 목록 보기
3. 각 자동차의 구매 가격 조회
4. 옵션이 있는 자동차 정보 조회
5. 빠른 자동차와 느린 자동차의 속도 차 조회
6. 프로그램 이용 종료
############################################
1~6 중 하나를 입력하세요:'''

자동차_리스트=[]
리스트최고속도=0
리스트최저속도=1000

while True :
    n = int(input(ui))
    if n == 1 :
        print('<자동차 정보입력>') 
        이름 = input('이름:')
        엔진가격 = int(input('엔진가격:'))
        타이어가격 = int(input('타이어가격:'))
        옵션유무 = input('옵션유무:')
        옵션이름 = input('옵션이름:')
        최고속도 = int(input('최고속도:'))
        리스트최고속도 = 리스트최고속도 if 리스트최고속도 > 최고속도 else 최고속도
        리스트최저속도 = 리스트최저속도 if 리스트최저속도 < 최고속도 else 최고속도
        구매가격 = 엔진가격 + 타이어가격
        자동차_정보 = { '이름':이름, '엔진가격':엔진가격, '타이어가격':타이어가격, '옵션유무':옵션유무, '옵션이름':옵션이름, '최고속도':최고속도
                  , '구매가격':구매가격 }
        자동차_리스트.append(자동차_정보)

        
    elif n==2:
        print('자동차목록')
        for i in range(len(자동차_리스트)):
            print(f'''{i+1}번 자동차
이름 = {자동차_리스트[i]['이름']}
엔진가격 = {자동차_리스트[i]['엔진가격']}
타이어가격 = {자동차_리스트[i]['타이어가격']}
옵션유무 = {자동차_리스트[i]['옵션유무']}
옵션이름 = {자동차_리스트[i]['옵션이름']}
최고속도 = {자동차_리스트[i]['최고속도']}
구매가격 = {자동차_리스트[i]['구매가격']}''')
    elif n==3:
        print('자동차구매가')
        for i in range(len(자동차_리스트)):
            print(f'''{i+1}번 자동차
이름 = {자동차_리스트[i]['이름']}
구매가격 = {자동차_리스트[i]['구매가격']}''')
    elif n==4:
        print('옵션잇는차')
        for i in range(len(자동차_리스트)):
            if 자동차_리스트[i]['옵션유무'] == '있음':
                print(f'''{i+1}번 자동차
이름 = {자동차_리스트[i]['이름']}
엔진가격 = {자동차_리스트[i]['엔진가격']}
타이어가격 = {자동차_리스트[i]['타이어가격']}
옵션유무 = {자동차_리스트[i]['옵션유무']}
옵션이름 = {자동차_리스트[i]['옵션이름']}
최고속도 = {자동차_리스트[i]['최고속도']}
구매가격 = {자동차_리스트[i]['구매가격']}''')
    elif n==5:
        print(f'빠차늦차속도차는 {리스트최고속도-리스트최저속도}입니다.')
    elif n==6:
        print('플그램종료')
        break        
    else:
        print('1~6입력해')

# %%
# 딕셔너리 안보고 치기5

# %%
# < 부호
# 인풋(ui)

ui = '''########### 자동차 정보 프로그램 ###########
1. 자동차 정보 입력
2. 저장된 목록 보기
3. 각 자동차의 구매 가격 조회
4. 옵션이 있는 자동차 정보 조회
5. 빠른 자동차와 느린 자동차의 속도 차 조회
6. 프로그램 이용 종료
############################################
1~6 중 하나를 입력하세요:'''

자동차_리스트=[]
리스트최고속도=0
리스트최저속도=99999

while True:
    n=int(input(ui))
    if n==1:
        print('자동차정보입력')
        이름=input('이름')
        엔진가격=int(input('엔진가격'))
        타이어가격=int(input('타이어가격'))
        옵션유무=input('옵션유무')
        옵션이름=input('옵션이름')
        최고속도=int(input('최고속도'))
        구매가격=엔진가격+타이어가격
        리스트최고속도=리스트최고속도 if 리스트최고속도>최고속도 else 최고속도
        리스트최저속도=리스트최저속도 if 리스트최저속도<최고속도 else 최고속도
        자동차_정보={'이름':이름, '엔진가격':엔진가격,'타이어가격':타이어가격,'옵션유무':옵션유무,
                        '옵션이름':옵션이름, '최고속도':최고속도, '구매가격':구매가격}
        자동차_리스트.append(자동차_정보)
    elif n==2:
        print('목록')
        for i in range(len(자동차_리스트)):
            print(f'''{i+1}번 자동차
이름:{자동차_리스트[i]['이름']}
엔진가격:{자동차_리스트[i]['엔진가격']}
타이어가격:{자동차_리스트[i]['타이어가격']}
옵션유무:{자동차_리스트[i]['옵션유무']}
옵션이름:{자동차_리스트[i]['옵션이름']}
최고속도:{자동차_리스트[i]['최고속도']}
구매가격:{자동차_리스트[i]['구매가격']}''')
    elif n==3:
        print('구매가')
        for i in range(len(자동차_리스트)):
            print(f'''{i+1}번 자동차
이름:{자동차_리스트[i]['이름']}
구매가격:{자동차_리스트[i]['구매가격']}''')
    elif n==4:
        print('옵션있는차')
        for i in range(len(자동차_리스트)):
            if 자동차_리스트[i]['옵션유무']=='있음':
                print(f'''{i+1}번 자동차
이름:{자동차_리스트[i]['이름']}
엔진가격:{자동차_리스트[i]['엔진가격']}
타이어가격:{자동차_리스트[i]['타이어가격']}
옵션유무:{자동차_리스트[i]['옵션유무']}
옵션이름:{자동차_리스트[i]['옵션이름']}
최고속도:{자동차_리스트[i]['최고속도']}
구매가격:{자동차_리스트[i]['구매가격']}''')
    elif n==5:
        print(f'빠차와늦차의속도차는 {리스트최고속도-리스트최저속도}입니다.')
    elif n==6:
        print('플그램종료')
        break
    else:
        print('1~6을입력해')

# %%
#딕션화 안보고치기  6

# %%
#perfect

ui = '''########### 자동차 정보 프로그램 ###########
1. 자동차 정보 입력
2. 저장된 목록 보기
3. 각 자동차의 구매 가격 조회
4. 옵션이 있는 자동차 정보 조회
5. 빠른 자동차와 느린 자동차의 속도 차 조회
6. 프로그램 이용 종료
############################################
1~6 중 하나를 입력하세요:'''

자동차_리스트=[]
리스트최고속도=0
리스트최저속도=999999

while True:
    n=int(input(ui))
    if n==1:
        print('자동차정보입력')
        print('-'*90)
        이름=input('이름')
        엔진가격=int(input('엔진가격'))
        타이어가격=int(input('타이어가격'))
        옵션유무=input('옵션유무')
        옵션이름=input('옵션이름')
        최고속도=int(input('최고속도'))
        구매가격= 엔진가격+타이어가격
        자동차_정보={'이름':이름,'엔진가격':엔진가격, '타이어가격':타이어가격, '옵션유무':옵션유무, '옵션이름':옵션이름,
                             '최고속도':최고속도, '구매가격':구매가격}
        자동차_리스트.append(자동차_정보)
        리스트최고속도=리스트최고속도 if 리스트최고속도>최고속도 else 최고속도
        리스트최저속도=리스트최저속도 if 리스트최저속도<최고속도 else 최고속도
        print('-'*90)
    elif n==2:
        print('목록')
        print('-'*90)
        for i in range(len(자동차_리스트)):
            print(f'''{i+1}번 자동차
이름:{자동차_리스트[i]['이름']}
엔진가격:{자동차_리스트[i]['엔진가격']}
타이어가격:{자동차_리스트[i]['타이어가격']}
옵션유무;{자동차_리스트[i]['옵션유무']}
옵션이름;{자동차_리스트[i]['옵션이름']}
최고속도:{자동차_리스트[i]['최고속도']}
구매가격:{자동차_리스트[i]['구매가격']}''')
            print('-'*90)
    elif n==3:
        print('구매가')
        print('-'*90)
        for i in range(len(자동차_리스트)):
            print(f'''{i+1}번 자동차
이름:{자동차_리스트[i]['이름']}
구매가격:{자동차_리스트[i]['구매가격']}''')
            print('-'*90)
    elif n==4:
        print('옵션잇는차')
        print('-'*90)
        for i in range(len(자동차_리스트)):
            if 자동차_리스트[i]['옵션유무'] == '있음':
                print(f'''{i+1}번 자동차
이름:{자동차_리스트[i]['이름']}
엔진가격:{자동차_리스트[i]['엔진가격']}
타이어가격:{자동차_리스트[i]['타이어가격']}
옵션유무;{자동차_리스트[i]['옵션유무']}
옵션이름;{자동차_리스트[i]['옵션이름']}
최고속도:{자동차_리스트[i]['최고속도']}
구매가격:{자동차_리스트[i]['구매가격']}''')
                print('-'*90)
    elif n==5:
        print('속도차')
        print('-'*90)
        print(f'빠차와늦차의속도차는 {리스트최고속도-리스트최저속도}입니다')
        print('-'*90)
    elif n==6:
        print('플그램종료')
        print('-'*90)
    else:
        print('1~6입력해')
        print('-'*90)

# %%
#클래스화 정리

# %%
ui = '''########### 자동차 정보 프로그램 ###########
1. 자동차 정보 입력
2. 저장된 목록 보기
3. 각 자동차의 구매 가격 조회
4. 옵션이 있는 자동차 정보 조회
5. 빠른 자동차와 느린 자동차의 속도 차 조회
6. 프로그램 이용 종료
############################################
1~6 중 하나를 입력하세요:'''

#객체생성시 초기화를 목적으로 자동으로 한번 동작하는 메소드
class 자동차정보:
    def __init__(self,이름,엔진가격,타이어가격,옵션유무,옵션이름,최고속도,구매가격):
        self.이름=이름
        self.엔진가격=엔진가격
        self.타이어가격=타이어가격
        self.옵션유무=옵션유무
        self.옵션이름=옵션이름
        self.최고속도=최고속도
        self.구매가격=구매가격

자동차_리스트=[]
리스트최고속도=0
리스트최저속도=99999

while True:
    n=int(input(ui))
    if n==1:
        print('자동차정보입력')
        이름=input('이름:')
        엔진가격=int(input('엔진가격:'))
        타이어가격=int(input('타이어가격:'))
        옵션유무=input('옵션유무(있음/없음):')
        if 옵션유무 !='없음' :
            옵션이름=input('옵션이름:')  #옵션 있을 때 옵션이름 입력
        else:
            옵션이름=옵션유무   # 옵션 없을 때 없음 그대로 옵션이름으로 입력
        최고속도=int(input('최고속도:'))
        구매가격=엔진가격+타이어가격
        자동차_정보 = 자동차정보(이름,엔진가격,타이어가격,옵션유무,옵션이름,최고속도,구매가격)
           #자동차정보  슈퍼클래스
        자동차_리스트.append(자동차_정보)
        리스트최고속도=리스트최고속도 if 리스트최고속도>최고속도 else 최고속도
        리스트최저속도=리스트최저속도 if 리스트최저속도<최고속도 else 최고속도
        print('정보 등록 완료')
    elif n==2:
        print('자동차 목록')
        for i, n in enumerate(자동차_리스트) :   #인덱스와 원소를 같이 뽑는 함수, 인덱과 원소를 컴마로
                      #  분리시키지 않으면 튜플로 한번에 뽑힌다  # 인덱스값을 1부터시작하고 싶으면 스타트=1
            print(f'''{i}번 차량
이름 = {n.이름}
엔진가격 = {n.엔진가격}
타이어가격 = {n.타이어가격}
옵션유무 =   {n.옵션유무}
옵션이름 = {n.옵션이름}
최고속도 = {n.최고속도}
구매가격 = {n.구매가격}''')
        print('목록 끝')
    elif n==3:
        print('자동차 구매가 조회')
        for i, n in enumerate(자동차_리스트):                      
            print(f'''{i}번 차량
이름 = {n.이름}
구매가격 = {n.구매가격}''')
        print('구매가조회끝')
    elif n==4:
        print('옵션 있는 차 조회')
        for i, n in enumerate(자동차_리스트) :  
            if n.옵션유무 == '있음' : 
                print(f'''{i}번 차량
이름 = {n.이름}
엔진가격 = {n.엔진가격}
타이어가격 = {n.타이어가격}
옵션유무 =   {n.옵션유무}
옵션이름 = {n.옵션이름}
최고속도 = {n.최고속도}
구매가격 = {n.구매가격}''')
        print('옵션있는차조회 끝')
    elif n==5:
        print('빠차와 늦차의 속도차 조회')
        print(f'빠차와 늦차의 속도차는 {리스트최고속도-리스트최저속도} 입니다')
        print('속도차조회 끝')
    elif n==6:
        print('프로그램종료')
        break
    else:
        print('1~6을입력해')

# %%
ui = '''########### 자동차 정보 프로그램 ###########
1. 자동차 정보 입력
2. 저장된 목록 보기
3. 각 자동차의 구매 가격 조회
4. 옵션이 있는 자동차 정보 조회
5. 빠른 자동차와 느린 자동차의 속도 차 조회
6. 프로그램 이용 종료
############################################
1~6 중 하나를 입력하세요:'''

#객체생성시 초기화를 목적으로 자동으로 한번 동작하는 메소드
class 자동차정보:
    def __init__(self,이름,엔진가격,타이어가격,옵션유무,옵션이름,최고속도,구매가격):
        self.이름=이름
        self.엔진가격=엔진가격
        self.타이어가격=타이어가격
        self.옵션유무=옵션유무
        self.옵션이름=옵션이름
        self.최고속도=최고속도
        self.구매가격=구매가격

자동차_리스트=[]
리스트최고속도=0
리스트최저속도=99999

while True:
    n=int(input(ui))
    if n==1:
        print('자동차정보입력')
        이름=input('이름:')
        엔진가격=int(input('엔진가격:'))
        타이어가격=int(input('타이어가격:'))
        옵션유무=input('옵션유무(있음/없음):')
        if 옵션유무 !='없음' :
            옵션이름=input('옵션이름:')  #옵션 있을 때 옵션이름 입력
        else:
            옵션이름=옵션유무   # 옵션 없을 때 없음 그대로 옵션이름으로 입력
        최고속도=int(input('최고속도:'))
        구매가격=엔진가격+타이어가격
        자동차_정보 = 자동차정보(이름,엔진가격,타이어가격,옵션유무,옵션이름,최고속도,구매가격)
           #자동차정보  슈퍼클래스
        자동차_리스트.append(자동차_정보)
        리스트최고속도=리스트최고속도 if 리스트최고속도>최고속도 else 최고속도
        리스트최저속도=리스트최저속도 if 리스트최저속도<최고속도 else 최고속도
        print('정보 등록 완료')
    elif n==2:
        print('자동차 목록')
        for i, 자동차 in enumerate(자동차_리스트):
            print(f'''{i}번 차량
이름 = {자동차.이름}
엔진가격 = {자동차.엔진가격}
타이어가격 = {자동차.타이어가격}
옵션유무 =   {자동차.옵션유무}
옵션이름 = {자동차.옵션이름}
최고속도 = {자동차.최고속도}
구매가격 = {자동차.구매가격}''')
        print('목록 끝')
    elif n==3:
        print('자동차 구매가 조회')
        for i, 자동차 in enumerate(자동차_리스트) :                     
            print(f'''{i}번 차량
이름 = {자동차.이름}
구매가격 = {자동차.구매가격}''')
        print('구매가조회끝')
    elif n==4:
        print('옵션 있는 차 조회')
        for i, 자동차 in enumerate(자동차_리스트)   :
            if 자동차.옵션유무 == '있음' : 
                print(f'''{i}번 차량
이름 = {자동차.이름}
엔진가격 = {자동차.엔진가격}
타이어가격 = {자동차.타이어가격}
옵션유무 =   {자동차.옵션유무}
옵션이름 = {자동차.옵션이름}
최고속도 = {자동차.최고속도}
구매가격 = {자동차.구매가격}''')
                print('옵션있는차조회 끝')
    elif n==5:
        print('빠차와 늦차의 속도차 조회')
        print(f'빠차와 늦차의 속도차는 {리스트최고속도-리스트최저속도} 입니다')
        print('속도차조회 끝')
    elif n==6:
        print('프로그램종료')
        break
    else:
        print('1~6을입력해')

# %%
# 클래스화 1차 안보고 치기

# %%
# 슈퍼클래스  def init 끝에 : 안함
# if 옵션유무 == '있음'    들여쓰기 에러
# 첫input() 에 ui 안적음
# 지역 인풋()애 전부 실수

ui = '''########### 자동차 정보 프로그램 ###########
1. 자동차 정보 입력
2. 저장된 목록 보기
3. 각 자동차의 구매 가격 조회
4. 옵션이 있는 자동차 정보 조회
5. 빠른 자동차와 느린 자동차의 속도 차 조회
6. 프로그램 이용 종료
############################################
1~6 중 하나를 입력하세요:'''

자동차_리스트=[]
리스트최고속도=0
리스트최저속도=99999

class 자동차정보:
    def __init__(self,이름,엔진가격,타이어가격,옵션유무,옵션이름,최고속도,구매가격):
        self.이름=이름
        self.엔진가격=엔진가격
        self.타이어가격=타이어가격
        self.옵션유무=옵션유무
        self.옵션이름=옵션이름
        self.최고속도=최고속도
        self.구매가격=구매가격

while True:
    n=int(input(ui))
    if n==1:
        print('자동차정보를입력해')
        이름=input('이름:')
        엔진가격=int(input('엔진가격:'))
        타이어가격=int(input('타이어가격:'))
        옵션유무=input('옵션유무:')
        if 옵션유무 == '있음' :
                옵션이름=input('옵션이름:')
        else:
                옵션이름=옵션유무    
        최고속도=int(input('최고속도:'))
        구매가격=엔진가격+타이어가격
        리스트최고속도=리스트최고속도 if 리스트최고속도>최고속도 else 최고속도
        리스트최저속도=리스트최저속도 if 리스트최저속도<최고속도 else 최고속도
        자동차_정보=자동차정보(이름,엔진가격,타이어가격,옵션유무,옵션이름,최고속도,구매가격)
        자동차_리스트.append(자동차_정보)
        print('정보입력종료')
    elif n==2:
        print('자동차 목록')
        for i,자동차 in enumerate(자동차_리스트) : #스트타로 해보세이@@@@@
            print(f'''{i+1}번 차
이름:{자동차.이름}
엔진가격:{자동차.엔진가격}
타이어가격:{자동차.타이어가격}
옵션유무:{자동차.옵션유무}
옵션이름:{자동차.옵션이름}
최고속도:{자동차.최고속도}
구매가격:{자동차.구매가격}''')
        print('자동차목록 종료')
    elif n==3:
        print('구매가 조회')
        for i,자동차 in enumerate(자동차_리스트):  #스트타로 해보세이@@@@@
            print(f'''{i+1}번 차
이름:{자동차.이름}
구매가격:{자동차.구매가격}''')
        print('구매가조회 종료')
    elif n==4:
        print('옵션잇는차 목록')
        for i,자동차 in enumerate(자동차_리스트):  #스트타로 해보세이@@@@@
            if 자동차.옵션유무 == '있음':    
                print(f'''{i+1}번 차
이름:{자동차.이름}
엔진가격:{자동차.엔진가격}
타이어가격:{자동차.타이어가격}
옵션유무:{자동차.옵션유무}
옵션이름:{자동차.옵션이름}
최고속도:{자동차.최고속도}
구매가격:{자동차.구매가격}''')
        print('옵션잇는차 목록 종료')
    elif n==5:
        print('빠차와늦차의 속도차 조회')
        print(f'빠차와 늦차의 속도차는 {리스트최고속도-리스트최저속도}입니다.')
        print('빠차와늦차의 속도차 조회 종료')
    elif n==6:
        print('프로그램종료')
        break
    else:
        print('1~6을입력해')

# %%
# 클래스화 1차 안보고 치기 2

# %%
# if n == 에서 n전부뺴머금
# 지역인풋안에 안내문 또 안바꿈

ui = '''########### 자동차 정보 프로그램 ###########
1. 자동차 정보 입력
2. 저장된 목록 보기
3. 각 자동차의 구매 가격 조회
4. 옵션이 있는 자동차 정보 조회
5. 빠른 자동차와 느린 자동차의 속도 차 조회
6. 프로그램 이용 종료
############################################
1~6 중 하나를 입력하세요:'''

자동차_리스트=[]
리스트최고속도=0
리스트최저속도=99999

class 자동차정보:
    def __init__(self,이름,엔진가격,타이어가격,옵션유무, 옵션이름,최고속도,구매가격):
        self.이름=이름
        self.엔진가격=엔진가격
        self.타이어가격=타이어가격
        self.옵션유무=옵션유무
        self.옵션이름=옵션이름
        self.최고속도=최고속도
        self.구매가격=구매가격

while True:
    n=int(input(ui))
    if n==1:
        print('자동차정보를입력해라')
        이름=input('이름')
        엔진가격=int(input('엔진가격'))
        타이어가격=int(input('타이어가격'))
        옵션유무=input('옵션유무')
        if 옵션유무=='있음':
            옵션이름=input('옵션이름')
        else:
            옵션유무=옵션이름    
        최고속도=int(input('최고속도'))
        구매가격=엔진가격+타이어가격
        리스트최고속도=리스트최고속도 if 리스트최고속도 > 최고속도 else 최고속도
        리스트최저속도=리스트최저속도 if 리스트최저속도 < 최고속도 else 최고속도
        자동차_정보=자동차정보(이름,엔진가격,타이어가격,옵션유무,옵션이름,최고속도,구매가격)
        자동차_리스트.append(자동차_정보)
        print('정보입력종료')
    elif n== 2 :
        print('저장목록보기')
        for i, 자동차 in enumerate(자동차_리스트):
            print(f'''{i+1}번 차
이름:{자동차.이름}
엔진가격:{자동차.엔진가격}
타이어가격:{자동차.타이어가격}
옵션유무:{자동차.옵션유무}
옵션이름:{자동차.옵션이름}
최고속도:{자동차.최고속도}
구매가격:{자동차.구매가격}''')
        print('저장목록보기 종료')
    elif n==3:
        print('각자동차구매가보기')
        for i, 자동차 in enumerate(자동차_리스트):
            print(f'''{i+1}번 차
이름:{자동차.이름}
구매가격:{자동차.구매가격}''')
        print('구매가보기 종료')
    elif n==4:
        print('옵션잇는차보기')
        for i, 자동차 in enumerate(자동차_리스트):
            if 자동차.옵션유무 == '있음' :
                print(f'''{i+1}번 차
이름:{자동차.이름}
엔진가격:{자동차.엔진가격}
타이어가격:{자동차.타이어가격}
옵션유무:{자동차.옵션유무}
옵션이름:{자동차.옵션이름}
최고속도:{자동차.최고속도}
구매가격:{자동차.구매가격}''')
        print('옵션차보기 종료')
    elif n==5:
        print('속도차보기')
        print(f'빠차늦차의속도차는 {리스트최고속도-리스트최저속도}입니다')
        print('속도차보기 종료')

    elif n==6:
        print('플그램종료')
        break
    else:
        print('1~6을입력해')

# %%
#클래스화 정리.

# %%
ui = '''########### 자동차 정보 프로그램 ###########
1. 자동차 정보 입력
2. 저장된 목록 보기
3. 각 자동차의 구매 가격 조회
4. 옵션이 있는 자동차 정보 조회
5. 빠른 자동차와 느린 자동차의 속도 차 조회
6. 프로그램 이용 종료
############################################
1~6 중 하나를 입력하세요:'''

#객체생성시 초기화를 목적으로 자동으로 한번 동작하는 메소드
class 자동차정보:
    def __init__(self,이름,엔진가격,타이어가격,옵션유무,옵션이름,최고속도,구매가격):
        self.이름=이름
        self.엔진가격=엔진가격
        self.타이어가격=타이어가격
        self.옵션유무=옵션유무
        self.옵션이름=옵션이름
        self.최고속도=최고속도
        self.구매가격=구매가격

자동차_리스트=[]
리스트최고속도=0
리스트최저속도=99999

while True:
    n=int(input(ui))
    if n==1:
        print('자동차정보입력')
        이름=input('이름:')
        엔진가격=int(input('엔진가격:'))
        타이어가격=int(input('타이어가격:'))
        옵션유무=input('옵션유무(있음/없음):')
        if 옵션유무 !='없음' :
            옵션이름=input('옵션이름:')  #옵션 있을 때 옵션이름 입력
        else:
            옵션이름=옵션유무   # 옵션 없을 때 없음 그대로 옵션이름으로 입력
        최고속도=int(input('최고속도:'))
        구매가격=엔진가격+타이어가격
        자동차_정보 = 자동차정보(이름,엔진가격,타이어가격,옵션유무,옵션이름,최고속도,구매가격)
           #자동차정보  슈퍼클래스
        자동차_리스트.append(자동차_정보)
        리스트최고속도=리스트최고속도 if 리스트최고속도>최고속도 else 최고속도
        리스트최저속도=리스트최저속도 if 리스트최저속도<최고속도 else 최고속도
        print('정보 등록 완료')
    elif n==2:
        print('자동차 목록')
        for i, 자동차 in enumerate(자동차_리스트,start=1):
            print(f'''{i}번 차량
이름 = {자동차.이름}
엔진가격 = {자동차.엔진가격}
타이어가격 = {자동차.타이어가격}
옵션유무 =   {자동차.옵션유무}
옵션이름 = {자동차.옵션이름}
최고속도 = {자동차.최고속도}
구매가격 = {자동차.구매가격}''')
        print('목록 끝')
    elif n==3:
        print('자동차 구매가 조회')
        for i, 자동차 in enumerate(자동차_리스트,start=1) :                     
            print(f'''{i}번 차량
이름 = {자동차.이름}
구매가격 = {자동차.구매가격}''')
        print('구매가조회끝')
    elif n==4:
        print('옵션 있는 차 조회')
        for i, 자동차 in enumerate(자동차_리스트,start=1)   :
            if 자동차.옵션유무 == '있음' : 
                print(f'''{i}번 차량
이름 = {자동차.이름}
엔진가격 = {자동차.엔진가격}
타이어가격 = {자동차.타이어가격}
옵션유무 =   {자동차.옵션유무}
옵션이름 = {자동차.옵션이름}
최고속도 = {자동차.최고속도}
구매가격 = {자동차.구매가격}''')
                print('옵션있는차조회 끝')
    elif n==5:
        print('빠차와 늦차의 속도차 조회')
        print(f'빠차와 늦차의 속도차는 {리스트최고속도-리스트최저속도} 입니다')
        print('속도차조회 끝')
    elif n==6:
        print('프로그램종료')
        break
    else:
        print('1~6을입력해')

# %%
#함수화 정리

# %%
ui = '''########### 자동차 정보 프로그램 ###########
1. 자동차 정보 입력
2. 저장된 목록 보기
3. 각 자동차의 구매 가격 조회
4. 옵션이 있는 자동차 정보 조회
5. 빠른 자동차와 느린 자동차의 속도 차 조회
6. 프로그램 이용 종료
############################################
1~6 중 하나를 입력하세요:'''

class 자동차정보:
    def __init__(self,이름,엔진가격,타이어가격,옵션유무,옵션이름,최고속도,구매가격):
        self.이름=이름
        self.엔진가격=엔진가격
        self.타이어가격=타이어가격
        self.옵션유무=옵션유무
        self.옵션이름=옵션이름
        self.최고속도=최고속도
        self.구매가격=구매가격

def f1():
    global 리스트최고속도, 리스트최저속도
    print('자동차 정보 입력')
    이름=input('이름:')
    엔진가격=int(input('엔진가격:'))
    타이어가격=int(input('타이어가격:'))
    옵션유무=input('옵션유무(있음/없음):')
    if 옵션유무 == '있음':
        옵션이름 = input('옵션이름:')
    else :
        옵션이름 = 옵션유무
    최고속도=int(input('최고속도:'))
    구매가격=엔진가격+타이어가격
    리스트최고속도=리스트최고속도 if 리스트최고속도>최고속도 else 최고속도
    리스트최저속도=리스트최저속도 if 리스트최저속도<최고속도 else 최고속도
    자동차_정보 = 자동차정보(이름,엔진가격,타이어가격,옵션유무,옵션이름,최고속도,구매가격)
    자동차_리스트.append(자동차_정보)
    print('정보 입력 종료')

def f2():
    print('차 목록 조회')
    if len(자동차_리스트)<=0:
        print('동록차량이 없음')
    for i, 자동차 in enumerate(자동차_리스트, start=1):
        print(f'''{i}번 차
이름:{자동차.이름}
엔진가격:{자동차.엔진가격}
타이어가격:{자동차.타이어가격}
옵션유무:{자동차.옵션유무}
옵션이름:{자동차.옵션이름}
최고속도:{자동차.최고속도}
구매가격:{자동차.구매가격}''')
    print('차목록조회 끝')

def f3():
    print('구매가 조회')
    if len(자동차_리스트)<=0:
        print('동록차량이 없음')
    for i, 자동차 in enumerate(자동차_리스트, start=1):
        print(f'''{i}번 차
이름:{자동차.이름}
구매가격:{자동차.구매가격}''')
    print('구매가조회 끝')

def f4():
    ck=1 # 조건문에 트루값을 주기위한
    print('옵션차 조회')
    if len(자동차_리스트)<=0:
        print('동록차량이 없음')
    for i, 자동차 in enumerate(자동차_리스트, start=1):
        if 자동차.옵션유무=='있음':
            ck=0 #조건문에 폴스값을 주기 위한
            print(f'''{i}번 차
이름:{자동차.이름}
엔진가격:{자동차.엔진가격}
타이어가격:{자동차.타이어가격}
옵션유무:{자동차.옵션유무}
옵션이름:{자동차.옵션이름}
최고속도:{자동차.최고속도}
구매가격:{자동차.구매가격}''')
    if ck: #옵션차가 있을 때 ck가 0이들어오면서 폴스값으로 출력되지 않음 옵션차가 없을 때 시케이는=1 트루값으로 출력
        print('옵션차가 없습니다')
    print('옵션차조회 끝')

def f5():
    print('속도차 조회')
    if len(자동차_리스트) >= 2 :
        print(f'빠차와 늦차의 속도차는 {리스트최고속도-리스트최저속도}입니다.')
    else:
        print('등록차량이2대이상이어야합니다')    
    print('속도차 조회 끝')

def f6():
    print('프로그램종료')
    return True

def f7():
    print('1~6을입력해')

def main():
    n=int(input(ui))
    모델=[f1,f2,f3,f4,f5,f6,f7]
    if 1<=n<=6:
        return 모델[n-1]()
    else:
        return 모델[-1]()

자동차_리스트=[]
리스트최고속도=0
리스트최저속도=999999999
run=False
                                 
if __name__ == '__main__':     #실행문
    while not run:
        run=main()
    else:
        print('프로그램이 종료됩니다.')

#def main():
#    n=int(input(ui))
#    if n==1:
#        f1()
#    elif n==2:
#        f2()
#    elif n==3:
#        f3()
#    elif n==4:
#        f4()
#    elif n==5:
#        f5()
#    elif n==6:
#        f6()
#    else: 
#        f7()

#실행문
#if __name__ == '__main__':
#    while not run:
#        run=main()
#    else:
#        print('프로그램이 종료됩니다.')
