# %% [markdown]
# # Q1 가위바위보 게임

# %%
import random
게임수=[]
while True:
   
    n1=input(f'가위바위보 게임을 시작합니다. 가위,바위,보 중 하나를 입력하세요.:')
    n2=['가위','바위','보']
    n3=random.sample(n2,1)
    print(f'컴퓨터:{n3}')

    if n1=='가위' and '가위' in n3:
        print('비김')
        게임수.append(3)
    elif n1=='가위' and '바위' in n3:
        print('패배')
        게임수.append(2)
        break
    elif n1=='가위' and '보' in n3:
        print('승리')
        게임수.append(1)

    elif n1=='바위' and '가위' in n3:
        print('승리')
        게임수.append(1)
    elif n1=='바위' and '바위' in n3:
        print('비김')
        게임수.append(3)
    elif n1=='바위' and '보' in n3:
        print('패배')
        게임수.append(2)
        break

    elif n1=='보' and '가위' in n3:
        print('패배')
        게임수.append(2)
        break
    elif n1=='보' and '바위' in n3:
        print('승리')
        게임수.append(1)
    elif n1=='보' and '보' in n3:
        print('비김')    
        게임수.append(3)
print()
print(f'''결과
게임수:{len(게임수)}회 승리:{게임수.count(1)}회''')
# Out:
# 가위바위보 게임을 시작합니다. 가위,바위,보 중 하나를 입력하세요.:가위
# 컴퓨터:['보']
# 승리
# 가위바위보 게임을 시작합니다. 가위,바위,보 중 하나를 입력하세요.:바위
# 컴퓨터:['보']
# 패배
#
# 결과
# 게임수:2회 승리:1회

# %% [markdown]
# # Q2 대/소문자 치환 프로그램

# %%
run=False
while not run:
    n=input('알파벳을입력하세요.:')
    for i in n:
        if ord('A') <= ord(i) <= ord('Z'): 
            pass
        elif ord('a') <= ord(i) <= ord('z'): 
            pass     
        elif ' ' in n:
            pass     
        else:
            run=True
    print(f'''입력:{n}
출력:{n.swapcase()}''')
else:
    print('프로그램이 종료됩니다.')
# Out:
# 알파벳을입력하세요.:aAa
# 입력:aAa
# 출력:AaA
# 알파벳을입력하세요.:ㅇㄹ
# 입력:ㅇㄹ
# 출력:ㅇㄹ
# 프로그램이 종료됩니다.

# %% [markdown]
# # Q3 입력한 문자열에서 숫자, 영문 소문자, 영문 대문자, 한글, 기타 문자를 골라서 출력

# %%
n=input('문자열을 입력하세요:')

대문자=''
소문자=''
숫자=''
한글=''
기타=''

for i in n:
    if ord('A') <= ord(i) <= ord('Z'): 
        대문자 += i 
    elif ord('a') <= ord(i) <= ord('z'): 
        소문자 += i
    elif ord('0') <= ord(i) <= ord('9'):
        숫자 += i
    elif ord('가') <= ord(i) <= ord('힣'): 
        한글 += i
    else:
        기타 += i

print(f'''대문자:{대문자}
소문자:{소문자}
숫자:{숫자}
한글:{한글}
기타:{기타}''')
# Out:
# 문자열을 입력하세요:Aa!@12가나
# 대문자:A
# 소문자:a
# 숫자:12
# 한글:가나
# 기타:!@

# %% [markdown]
# # Q4 10진수의 인풋을 2/8/16 진수로 변환하는 코드

# %%
n=int(input('10진수 입력:'))
print(f'''2진수:{(' ').join(bin(n)[2:])}
8진수:{(' ').join(oct(n)[2:])}
16진수:{(' ').join(hex(n)[2:])}''')
# Out:
# 10진수 입력:344
# 2진수:1 0 1 0 1 1 0 0 0
# 8진수:5 3 0
# 16진수:1 5 8

# %% [markdown]
# # Q5  주사위 게임

# %%
import random

사람경기내용=[]
컴퓨터경기내용=[]
승패=[]

n1=[1,2,3,4,5,6]

게임횟수=int(input('게임횟수를 입력하시오:'))
print(f'게임을 {게임횟수}회 시작합니다.')

for i in range(게임횟수):
    컴퓨터주사위=random.sample(n1,1)  #n1에서 하나를 뽑는다
    print(f'''
{i+1}회차
컴퓨터:{컴퓨터주사위}     
주사위를 굴리시오''',end='') 
    input()   
    사람주사위=random.sample(n1,1)
    print(f'플레이어:{사람주사위}')
    사람경기내용.append(사람주사위)
    컴퓨터경기내용.append(컴퓨터주사위)
    if 사람주사위 > 컴퓨터주사위 :
        승패.append('승리')
    elif 사람주사위 < 컴퓨터주사위 :
        승패.append('패배')
    elif 사람주사위 == 컴퓨터주사위 :
        승패.append('비김')
print('결과')
print(f'{게임횟수}번 경기내용')
for i in range(게임횟수) :
    print(f'''{i+1}회차 - 플레이어:{사람경기내용[i]}, 컴퓨터:{컴퓨터경기내용[i]} {승패[i]}''')

print(f"게임수:{게임횟수}회 승리:{승패.count('승리')}회 비김:{승패.count('비김')}회 패배:{승패.count('패배')}회")
# Out:
# 게임횟수를 입력하시오:5
# 게임을 5회 시작합니다.
#
# 1회차
# 컴퓨터:[6]
# 주사위를 굴리시오
# 플레이어:[4]
#
# 2회차
# 컴퓨터:[4]
# 주사위를 굴리시오
# 플레이어:[1]
#
# 3회차
# 컴퓨터:[5]
# 주사위를 굴리시오
# 플레이어:[3]
#
# 4회차
# 컴퓨터:[2]
# 주사위를 굴리시오
# 플레이어:[6]
#
# 5회차
# 컴퓨터:[2]
# 주사위를 굴리시오
# 플레이어:[4]
# 결과
# 5번 경기내용
# 1회차 - 플레이어:[4], 컴퓨터:[6] 패배
# 2회차 - 플레이어:[1], 컴퓨터:[4] 패배
# 3회차 - 플레이어:[3], 컴퓨터:[5] 패배
# 4회차 - 플레이어:[6], 컴퓨터:[2] 승리
# 5회차 - 플레이어:[4], 컴퓨터:[2] 승리
# 게임수:5회 승리:2회 비김:0회 패배:3회

# %% [markdown]
# # Q6 계좌관리프로그램

# %%
import pickle
class bank:
    ui='''--------------------------------------- 계좌 관리 프로그램 --------------------------------------- 
1. 계좌생성 | 2. 계좌 목록 | 3. 예금하기 | 4. 출금하기 | 5. 송금 | 6. 내역조회 | 7. 프로그램 종료 
--------------------------------------------------------------------------------------------------
기능 1~7 중 하나를 입력하세요.:'''
    #클래스필드
    계좌_리스트=[]
    #생성자
    def __init__(self,이름,은행이름,계좌번호,예금액,내역):
        self.이름=이름
        self.은행이름=은행이름
        self.계좌번호=계좌번호
        self.예금액=예금액
        self.내역=내역
    #출력값
    def __repr__(self):
        return f'''이름:{self.이름}
은행이름:{self.은행이름}
계좌번호:{self.계좌번호}
남은금액:{self.예금액}'''
    #클래스메서드
    @classmethod  #1. 계좌 생성(계좌번호 입력)
    def f1(cls):
        print()
        print('계좌를 생성하기 위한 이름,은행이름,계좌번호,초기입금액을 입력하세요.')
        print()
        이름=input('이름:')
        은행이름=input('은행이름:')
        계좌번호=int(input('계좌번호(-없이입력):'))
        초기입금액=int(input('초기입금액:'))
        예금액=초기입금액  #계좌잔액
        내역=[초기입금액]  #계좌내역조회를위한리스트
        계좌_정보=bank(이름,은행이름,계좌번호,예금액,내역)
        cls.계좌_리스트.append(계좌_정보)
        print()
        print('새 계좌가 생성되었습니다.')
        print()
    @classmethod # 2. 계좌 목록
    def f2(cls):
        print()
        if len(cls.계좌_리스트)<=0:
            print('등록된 계좌가 하나도 없습니다.')
            print()
            return
        for i,계좌 in enumerate(cls.계좌_리스트): 
            print(f'''{i+1}번 계좌
{계좌}''')
            print()    
        print('계좌 목록 조회 완료')
        print()
    @classmethod # 3. 예금하기
    def f3(cls):
        print()
        if len(cls.계좌_리스트)<=0:
            print()
            print('등록된 계좌가 하나도 없습니다.')
            print()
            return
        for i,계좌 in enumerate(cls.계좌_리스트):
            print() 
            print(f'''등록 번호 {i+1}번 계좌
{계좌}''')
            print()
        nnn_1=int(input('예금할 계좌의 등록번호를 입력하세요.:'))
        nnn_2=int(input('예금할 금액을 숫자만 입력하세요.:'))    
        cls.계좌_리스트[nnn_1-1].예금액 += nnn_2  #계좌잔액업데이트
        cls.계좌_리스트[nnn_1-1].내역.append(nnn_2)  #내역조회를위한 내역리스트에 어펜드
        print(f'''{nnn_1}번 계좌에 {nnn_2}원을 입금하여 
예금액이 {cls.계좌_리스트[nnn_1-1].예금액}원이 되었습니다.''')
        print()

    @classmethod # 4. 출금하기
    def f4(cls):
        print()
        if len(cls.계좌_리스트)<=0:
            print('등록된 계좌가 하나도 없습니다.')
            print()
            return
        for i,계좌 in enumerate(cls.계좌_리스트): 
            print(f'''등록 번호 {i+1}번 계좌
{계좌}''')
            print()
        ddd_1=int(input('출금할 계좌의 등록번호를 입력하세요.:'))
        ddd_2=int(input('출금할 금액을 숫자만 입력하세요.:'))    
        cls.계좌_리스트[ddd_1-1].예금액 -= ddd_2
        cls.계좌_리스트[ddd_1-1].내역.append(-ddd_2)
        print(f'''{ddd_1}번 계좌에 {ddd_2}원을 출금하여 
예금액이 {cls.계좌_리스트[ddd_1-1].예금액}원이 되었습니다.''')
        print()
    @classmethod # 5. 송금기능
    def f5(cls):
        print()
        if len(cls.계좌_리스트)<=1:
            print()
            print('계좌가 1개 이하입니다. 계좌가 2개 이상이어야 송금이 가능합니다,')
            print()
            return
        print('송금기능을 시작합니다. 안내에 따라주세요.')
        for i,계좌 in enumerate(cls.계좌_리스트):
            print() 
            print(f'''등록 번호 {i+1}번 계좌
{계좌}''')
            print()
        yyy_1=int(input('송금 받을 계좌의 등록번호를 입력하세요.:'))
        uuu_2=int(input('출금할 계좌의 등록번호를 입력하세요.:'))
        rrr_3=int(input('출금할 금액을 숫자만 입력하세요.:'))    
        cls.계좌_리스트[uuu_2-1].예금액 -= rrr_3
        cls.계좌_리스트[yyy_1-1].예금액 += rrr_3
        cls.계좌_리스트[yyy_1-1].내역.append(rrr_3)
        cls.계좌_리스트[uuu_2-1].내역.append(-rrr_3)
        print()
        print(f'{uuu_2}번 계좌에서 {rrr_3}원을 {yyy_1}번 계좌로 송금하였습니다') 
        print()
        print(f'''{yyy_1}번 계좌의 예금액이 {cls.계좌_리스트[yyy_1-1].예금액}원이 되었고
{uuu_2}번 계좌의 예금액이 {cls.계좌_리스트[uuu_2-1].예금액}원이 되었습니다.''')
        print()

    @classmethod # 6. 내역조회기능
    def f6(cls):
        print()
        if len(cls.계좌_리스트)<=0:
            print()
            print('계좌가 하나도 없습니다')
            print()
            return
        print('내역조회기능입니다.')
        print()
        for i,계좌 in enumerate(cls.계좌_리스트): 
            print(f'''등록번호 {i+1}번 계좌
{계좌}''')
            print()
        www_1=int(input('조회할 계좌의 등록번호를 입력하세요.:'))
        print()
        print(f'등록번호 {www_1}번 계좌의 내역 조회를 시작합니다.')
        print()
        for i, 계좌내역보기 in enumerate(cls.계좌_리스트[www_1-1].내역):
            print(f'''{i+1}번째 내역은 {계좌내역보기}원 입니다.''')
        print(f'잔액:{cls.계좌_리스트[www_1-1].예금액}원') 
        print()
        print('계좌내역조회가 끝났습니다.')
        print()

    @classmethod # 7. 프로그램 종료
    def f7(cls):
        print()
        pickle.dump( cls.계좌_리스트,open('bank_num_list' ,'wb')) 
        print('계좌_리스트를 저장하고 계좌 관리 프로그램을 종료합니다.')
        return True
        print()

    @classmethod
    def f8(cls):  #  8. 숫자잘못입력했을떄
        print()
        print('기능은 1~7뿐입니다. 다시 입력하세요.')
        print()
#메인문
def main() : 
    try:
        pickle.load(open('bank_num_list' ,'rb')) 
    except:
        print()
        print('등록된 계좌가 없습니다.')
        print()
    else:   
        print()
        bank.계좌_리스트=pickle.load(open('bank_num_list' ,'rb'))
        print('보유 중인 계좌 목록을 불러왔습니다.')
        print()
    try:
        run=False
        while not run:
            n=int(input(bank.ui))
            코드모델=[bank.f1,bank.f2,bank.f3,bank.f4,bank.f5,bank.f6,bank.f7,bank.f8]
            if 1<=n<=7:
                run=코드모델[n-1]()
            else:
                코드모델[-1]()
    except:
        print('잘못 입력하셨습니다. 프로그램을 재시작합니다.')
        main()
#실행문
if __name__=='__main__':
    main()
# Out:
# 보유 중인 계좌 목록을 불러왔습니다.
#
# --------------------------------------- 계좌 관리 프로그램 ---------------------------------------
# 1. 계좌생성 | 2. 계좌 목록 | 3. 예금하기 | 4. 출금하기 | 5. 송금 | 6. 내역조회 | 7. 프로그램 종료
# --------------------------------------------------------------------------------------------------
# 기능 1~7 중 하나를 입력하세요.:2
#
# 1번 계좌
# 이름:최세형
# 은행이름:농협
# 계좌번호:123456789
# 남은금액:10000
#
# 계좌 목록 조회 완료
#
# --------------------------------------- 계좌 관리 프로그램 ---------------------------------------
# 1. 계좌생성 | 2. 계좌 목록 | 3. 예금하기 | 4. 출금하기 | 5. 송금 | 6. 내역조회 | 7. 프로그램 종료
# --------------------------------------------------------------------------------------------------
# 기능 1~7 중 하나를 입력하세요.:1
#
# 계좌를 생성하기 위한 이름,은행이름,계좌번호,초기입금액을 입력하세요.
#
# 이름:최세진
# 은행이름:새마을금고
# 계좌번호(-없이입력):1234
# 초기입금액:20000
#
# 새 계좌가 생성되었습니다.
#
# --------------------------------------- 계좌 관리 프로그램 ---------------------------------------
# 1. 계좌생성 | 2. 계좌 목록 | 3. 예금하기 | 4. 출금하기 | 5. 송금 | 6. 내역조회 | 7. 프로그램 종료
# --------------------------------------------------------------------------------------------------
# 기능 1~7 중 하나를 입력하세요.:3
#
#
# 등록 번호 1번 계좌
# 이름:최세형
# 은행이름:농협
# 계좌번호:123456789
# 남은금액:10000
#
#
# 등록 번호 2번 계좌
# 이름:최세진
# 은행이름:새마을금고
# 계좌번호:1234
# 남은금액:20000
#
# 예금할 계좌의 등록번호를 입력하세요.:2
# 예금할 금액을 숫자만 입력하세요.:1000
# 2번 계좌에 1000원을 입금하여
# 예금액이 21000원이 되었습니다.
#
# --------------------------------------- 계좌 관리 프로그램 ---------------------------------------
# 1. 계좌생성 | 2. 계좌 목록 | 3. 예금하기 | 4. 출금하기 | 5. 송금 | 6. 내역조회 | 7. 프로그램 종료
# --------------------------------------------------------------------------------------------------
# 기능 1~7 중 하나를 입력하세요.:4
#
# 등록 번호 1번 계좌
# 이름:최세형
# 은행이름:농협
# 계좌번호:123456789
# 남은금액:10000
#
# 등록 번호 2번 계좌
# 이름:최세진
# 은행이름:새마을금고
# 계좌번호:1234
# 남은금액:21000
#
# 출금할 계좌의 등록번호를 입력하세요.:1
# 출금할 금액을 숫자만 입력하세요.:500
# 1번 계좌에 500원을 출금하여
# 예금액이 9500원이 되었습니다.
#
# --------------------------------------- 계좌 관리 프로그램 ---------------------------------------
# 1. 계좌생성 | 2. 계좌 목록 | 3. 예금하기 | 4. 출금하기 | 5. 송금 | 6. 내역조회 | 7. 프로그램 종료
# --------------------------------------------------------------------------------------------------
# 기능 1~7 중 하나를 입력하세요.:5
#
# 송금기능을 시작합니다. 안내에 따라주세요.
#
# 등록 번호 1번 계좌
# 이름:최세형
# 은행이름:농협
# 계좌번호:123456789
# 남은금액:9500
#
#
# 등록 번호 2번 계좌
# 이름:최세진
# 은행이름:새마을금고
# 계좌번호:1234
# 남은금액:21000
#
# 송금 받을 계좌의 등록번호를 입력하세요.:1
# 출금할 계좌의 등록번호를 입력하세요.:2
# 출금할 금액을 숫자만 입력하세요.:5500
#
# 2번 계좌에서 5500원을 1번 계좌로 송금하였습니다
#
# 1번 계좌의 예금액이 15000원이 되었고
# 2번 계좌의 예금액이 15500원이 되었습니다.
#
# --------------------------------------- 계좌 관리 프로그램 ---------------------------------------
# 1. 계좌생성 | 2. 계좌 목록 | 3. 예금하기 | 4. 출금하기 | 5. 송금 | 6. 내역조회 | 7. 프로그램 종료
# --------------------------------------------------------------------------------------------------
# 기능 1~7 중 하나를 입력하세요.:6
#
# 내역조회기능입니다.
#
# 등록번호 1번 계좌
# 이름:최세형
# 은행이름:농협
# 계좌번호:123456789
# 남은금액:15000
#
# 등록번호 2번 계좌
# 이름:최세진
# 은행이름:새마을금고
# 계좌번호:1234
# 남은금액:15500
#
# 조회할 계좌의 등록번호를 입력하세요.:1
#
# 등록번호 1번 계좌의 내역 조회를 시작합니다.
#
# 1번째 내역은 10000원 입니다.
# 2번째 내역은 -500원 입니다.
# 3번째 내역은 5500원 입니다.
# 잔액:15000원
#
# 계좌내역조회가 끝났습니다.
#
# --------------------------------------- 계좌 관리 프로그램 ---------------------------------------
# 1. 계좌생성 | 2. 계좌 목록 | 3. 예금하기 | 4. 출금하기 | 5. 송금 | 6. 내역조회 | 7. 프로그램 종료
# --------------------------------------------------------------------------------------------------
# 기능 1~7 중 하나를 입력하세요.:7
#
# 계좌_리스트를 저장하고 계좌 관리 프로그램을 종료합니다.
