# %%
import random
answer = random.randrange(1,101)
list_1 = []       # 시도 수 카운트를 위한 빈리스트 선언  + 인풋 순서 제출
while True:     
  inp=int(input('1~100 사이의 값을 입력하세요: '))     
  if inp != answer :                                     #  인풋이 정답과 다른 동안 인풋 받기
     if   1 <= inp <= 100 :        # 1~100 사이의  
        if answer > inp :          ## 임의의 정답 값(소스내에 상수로 지정)보다 입력된 숫자가 작으면 "Up" 출력.
              print("Up")
              list_1.append(inp)
        else:              # 1~100 사이의 임의의 정답 값(소스내에 상수로 지정)보다 입력된 숫자가 크면 "Down" 출력.
              print("Down")
              list_1.append(inp)  
     else:
            print('1~100 사이의 값이 아닙니다.')
            list_1.append(inp)
  else:          # 30 정답 맞췄을 때             #인풋이 30이면 프린트
     list_1.append(inp) # 시도 수 카운트
     x = len(list_1)  # 렌으로 원소 수 카운트  -시도 수
     print(f"{x}회째 정답!")
     print('*인풋 순서*')  #1번입력은 2 2번입력은 55 3번입력은 101 4번입력은 30
     for xx in range(x):   # x회째로 반복 
         if  xx+1 == x :    #끝값은 정답입니다 아닌값은 입니다                                            
             print(xx+1,'번째 인풋은', list_1[xx],'정답입니다')
         else:
             print(xx+1,'번째 인풋은', list_1[xx],'입니다') 
     break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     726         """
# --> 727         parts = [self.recv(flags, copy=copy, track=track)]
#     728         # have first part already, only loop while more to receive
#
# ...

# %%
def aaa():
  try:
          import random
          answer = random.randrange(1,101)
          list_1 = []       # 시도 수 카운트를 위한 빈리스트 선언  + 인풋 순서 제출
          while True:     
            inp=int(input('1~100 사이의 정수를 입력하세요: '))     
            if inp != answer :                                     #  인풋이 정답과 다른 동안 인풋 받기
               if   1 <= inp <= 100 :        # 1~100 사이의  
                  if answer > inp :          ## 임의의 정답 값(소스내에 상수로 지정)보다 입력된 숫자가 작으면 "Up" 출력.
                        print("Up")
                        list_1.append(inp)
                  else:              # 1~100 사이의 임의의 정답 값(소스내에 상수로 지정)보다 입력된 숫자가 크면 "Down" 출력.
                        print("Down")
                        list_1.append(inp)  
               else:
                    list_1.append(inp)
                    print('1~100 사이의 정수가 아닙니다. 다시 입력해주세요')
                    
            else:          # 30 정답 맞췄을 때             #인풋이 30이면 프린트
               list_1.append(inp) # 시도 수 카운트
               x = len(list_1)  # 렌으로 원소 수 카운트  -시도 수
               print(f"{x}회째 정답!")
               print('*인풋 순서*')  #1번입력은 2 2번입력은 55 3번입력은 101 4번입력은 30
               for xx in range(x):   # x회째로 반복 
                  if  xx+1 == x :    #끝값은 정답입니다 아닌값은 입니다                                            
                      print(xx+1,'번째 인풋은', list_1[xx],'정답입니다')
                  else:
                      print(xx+1,'번째 인풋은', list_1[xx],'입니다') 
               break
  except:
            list_1.append(inp)
            ('1~100 사이의 정수가 아닙니다. 다시 입력해주세요')
            aaa()    



try:
          import random
          answer = random.randrange(1,101)
          list_1 = []       # 시도 수 카운트를 위한 빈리스트 선언  + 인풋 순서 제출
          while True:     
            inp=int(input('1~100 사이의 정수를 입력하세요: '))     
            if inp != answer :                                     #  인풋이 정답과 다른 동안 인풋 받기
               if   1 <= inp <= 100 :        # 1~100 사이의  
                  if answer > inp :          ## 임의의 정답 값(소스내에 상수로 지정)보다 입력된 숫자가 작으면 "Up" 출력.
                        print("Up")
                        list_1.append(inp)
                  else:              # 1~100 사이의 임의의 정답 값(소스내에 상수로 지정)보다 입력된 숫자가 크면 "Down" 출력.
                        print("Down")
                        list_1.append(inp)  
               else:
                    list_1.append(inp)
                    print('1~100 사이의 정수가 아닙니다. 다시 입력해주세요')
                    
            else:          # 30 정답 맞췄을 때             #인풋이 30이면 프린트
               list_1.append(inp) # 시도 수 카운트
               x = len(list_1)  # 렌으로 원소 수 카운트  -시도 수
               print(f"{x}회째 정답!")
               print('*인풋 순서*')  #1번입력은 2 2번입력은 55 3번입력은 101 4번입력은 30
               for xx in range(x):   # x회째로 반복 
                  if  xx+1 == x :    #끝값은 정답입니다 아닌값은 입니다                                            
                      print(xx+1,'번째 인풋은', list_1[xx],'정답입니다')
                  else:
                      print(xx+1,'번째 인풋은', list_1[xx],'입니다') 
               break
except:
           list_1.append(inp)
           print('1~100 사이의 정수가 아닙니다. 다시 입력해주세요')
           aaa()    


#문제점1 인트를 입력하지 않았을 시  에러가 나고 트라이익셉으로 다시 시도하므로 
   # 정답시도목록으로 카운트되지 않고    '1~100 사이의 정수가 아닙니다. 다시 입력해주세요'가  출력되지 않음



################################################################
################################################################
################################################################
################################################################
################################################################
################################################################
################################################################
# Out:
# 1~100 사이의 정수를 입력하세요: 105
# 1~100 사이의 정수가 아닙니다. 다시 입력해주세요
# 1~100 사이의 정수를 입력하세요: 50
# Up
# 1~100 사이의 정수를 입력하세요: 70
# Up
# 1~100 사이의 정수를 입력하세요: 80
# Up
# 1~100 사이의 정수를 입력하세요: 90
# Down
# 1~100 사이의 정수를 입력하세요: 88
# Down
# 1~100 사이의 정수를 입력하세요: 85
# Up
# 1~100 사이의 정수를 입력하세요: 87
# Down
# 1~100 사이의 정수를 입력하세요: 86
# 9회째 정답!
# *인풋 순서*
# 1 번째 인풋은 105 입니다
# 2 번째 인풋은 50 입니다
# 3 번째 인풋은 70 입니다
# 4 번째 인풋은 80 입니다
# 5 번째 인풋은 90 입니다
# 6 번째 인풋은 88 입니다
# 7 번째 인풋은 85 입니다
# 8 번째 인풋은 87 입니다
# 9 번째 인풋은 86 정답입니다

# %%
def aaa():
  try:
          import random
          #answer = random.randrange(1,101)
          list_1 = []       # 시도 수 카운트를 위한 빈리스트 선언  + 인풋 순서 제출
          while True:     
            inp=int(input('1~100 사이의 정수를 입력하세요: '))     
            if inp != answer :                                     #  인풋이 정답과 다른 동안 인풋 받기
               if   1 <= inp <= 100 :        # 1~100 사이의  
                  if answer > inp :          ## 임의의 정답 값(소스내에 상수로 지정)보다 입력된 숫자가 작으면 "Up" 출력.
                        print("Up")
                        list_1.append(inp)
                  else:              # 1~100 사이의 임의의 정답 값(소스내에 상수로 지정)보다 입력된 숫자가 크면 "Down" 출력.
                        print("Down")
                        list_1.append(inp)  
               else:
                    list_1.append(inp)
                    print('1~100 사이의 정수가 아닙니다. 다시 입력해주세요')
                    
            else:          # 30 정답 맞췄을 때             #인풋이 30이면 프린트
               list_1.append(inp) # 시도 수 카운트
               x = len(list_1)  # 렌으로 원소 수 카운트  -시도 수
               print(f"{x}회째 정답!")
               print('*인풋 순서*')  #1번입력은 2 2번입력은 55 3번입력은 101 4번입력은 30
               for xx in range(x):   # x회째로 반복 
                  if  xx+1 == x :    #끝값은 정답입니다 아닌값은 입니다                                            
                      print(xx+1,'번째 인풋은', list_1[xx],'정답입니다')
                  else:
                      print(xx+1,'번째 인풋은', list_1[xx],'입니다') 
               break
  except:
            list_1.append(inp)
            ('1~100 사이의 정수가 아닙니다. 다시 입력해주세요')
            aaa()    



try:
          import random
          answer = random.randrange(1,101)
          list_1 = []       # 시도 수 카운트를 위한 빈리스트 선언  + 인풋 순서 제출
          while True:     
            inp=int(input('1~100 사이의 정수를 입력하세요: '))     
            if inp != answer :                                     #  인풋이 정답과 다른 동안 인풋 받기
               if   1 <= inp <= 100 :        # 1~100 사이의  
                  if answer > inp :          ## 임의의 정답 값(소스내에 상수로 지정)보다 입력된 숫자가 작으면 "Up" 출력.
                        print("Up")
                        list_1.append(inp)
                  else:              # 1~100 사이의 임의의 정답 값(소스내에 상수로 지정)보다 입력된 숫자가 크면 "Down" 출력.
                        print("Down")
                        list_1.append(inp)  
               else:
                    list_1.append(inp)
                    print('1~100 사이의 정수가 아닙니다. 다시 입력해주세요')
                    
            else:          # 30 정답 맞췄을 때             #인풋이 30이면 프린트
               list_1.append(inp) # 시도 수 카운트
               x = len(list_1)  # 렌으로 원소 수 카운트  -시도 수
               print(f"{x}회째 정답!")
               print('*인풋 순서*')  #1번입력은 2 2번입력은 55 3번입력은 101 4번입력은 30
               for xx in range(x):   # x회째로 반복 
                  if  xx+1 == x :    #끝값은 정답입니다 아닌값은 입니다                                            
                      print(xx+1,'번째 인풋은', list_1[xx],'정답입니다')
                  else:
                      print(xx+1,'번째 인풋은', list_1[xx],'입니다') 
               break
except:
           list_1.append(inp)
           print('1~100 사이의 정수가 아닙니다. 다시 입력해주세요')
           aaa()    


#문제점1 인트를 입력하지 않았을 시  에러가 나고 트라이익셉으로 다시 시도하므로 
   # 정답시도목록으로 카운트되지 않고    '1~100 사이의 정수가 아닙니다. 다시 입력해주세요'가  출력되지 않음
# Out:
# 1~100 사이의 정수를 입력하세요: *
# 1~100 사이의 정수가 아닙니다. 다시 입력해주세요
# 1~100 사이의 정수를 입력하세요: *
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-a7817dbadec0> in <module>()
#      42           while True:
# ---> 43             inp=int(input('1~100 사이의 정수를 입력하세요: '))
#      44             if inp != answer :                                     #  인풋이 정답과 다른 동안 인풋 받기
#
# ValueError: invalid literal for int() with base 10: '*'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-a7817dbadec0> in aaa()
#       6           while True:
# ----> 7             inp=int(input('1~100 사이의 정수를 입력하세요: '))
#       8             if inp != answer :                                     #  인풋이 정답과 다른 동안 인풋 받기
#
# ValueError: invalid literal for int() with base 10: '*'
#
# ...

# %%
def aaa():
  try:
          import random
          answer = random.randrange(1,101)
          list_1 = []       # 시도 수 카운트를 위한 빈리스트 선언  + 인풋 순서 제출
          while True:     
            inp=int(input('1~100 사이의 정수를 입력하세요: '))     
            if inp != answer :                                     #  인풋이 정답과 다른 동안 인풋 받기
               if   1 <= inp <= 100 :        # 1~100 사이의  
                  if answer > inp :          ## 임의의 정답 값(소스내에 상수로 지정)보다 입력된 숫자가 작으면 "Up" 출력.
                        print("Up")
                        list_1.append(inp)
                  else:              # 1~100 사이의 임의의 정답 값(소스내에 상수로 지정)보다 입력된 숫자가 크면 "Down" 출력.
                        print("Down")
                        list_1.append(inp)  
               else:
                    list_1.append(inp)
                    print('1~100 사이의 정수가 아닙니다. 다시 입력해주세요')
                    
            else:          # 30 정답 맞췄을 때             #인풋이 30이면 프린트
               list_1.append(inp) # 시도 수 카운트
               x = len(list_1)  # 렌으로 원소 수 카운트  -시도 수
               print(f"{x}회째 정답!")
               print('*인풋 순서*')  #1번입력은 2 2번입력은 55 3번입력은 101 4번입력은 30
               for xx in range(x):   # x회째로 반복 
                  if  xx+1 == x :    #끝값은 정답입니다 아닌값은 입니다                                            
                      print(xx+1,'번째 인풋은', list_1[xx],'정답입니다')
                  else:
                      print(xx+1,'번째 인풋은', list_1[xx],'입니다') 
               break
  except:
           list_1.append(inp)
           print('1~100 사이의 정수가 아닙니다. 다시 입력해주세요')
           aaa()  


try:
          import random
          answer = random.randrange(1,101)
          list_1 = []       # 시도 수 카운트를 위한 빈리스트 선언  + 인풋 순서 제출
          while True:     
            inp=int(input('1~100 사이의 정수를 입력하세요: '))     
            if inp != answer :                                     #  인풋이 정답과 다른 동안 인풋 받기
               if   1 <= inp <= 100 :        # 1~100 사이의  
                  if answer > inp :          ## 임의의 정답 값(소스내에 상수로 지정)보다 입력된 숫자가 작으면 "Up" 출력.
                        print("Up")
                        list_1.append(inp)
                  else:              # 1~100 사이의 임의의 정답 값(소스내에 상수로 지정)보다 입력된 숫자가 크면 "Down" 출력.
                        print("Down")
                        list_1.append(inp)  
               else:
                    list_1.append(inp)
                    print('1~100 사이의 정수가 아닙니다. 다시 입력해주세요')
                    
            else:          # 30 정답 맞췄을 때             #인풋이 30이면 프린트
               list_1.append(inp) # 시도 수 카운트
               x = len(list_1)  # 렌으로 원소 수 카운트  -시도 수
               print(f"{x}회째 정답!")
               print('*인풋 순서*')  #1번입력은 2 2번입력은 55 3번입력은 101 4번입력은 30
               for xx in range(x):   # x회째로 반복 
                  if  xx+1 == x :    #끝값은 정답입니다 아닌값은 입니다                                            
                      print(xx+1,'번째 인풋은', list_1[xx],'정답입니다')
                  else:
                      print(xx+1,'번째 인풋은', list_1[xx],'입니다') 
               break
except:
           list_1.append(inp)
           print('1~100 사이의 정수가 아닙니다. 다시 입력해주세요')
           aaa()    


#문제점1 인트를 입력하지 않았을 시 list_1.append(inp) 에서 에러가 나고 트라이익셉으로 다시 시도하므로 
   # 정답시도목록으로 카운트되지 않고
# 처음연속두번 인트가 아닌 것을 입력시   에러가 난다  데프로 들어가면 aaa가정의되지않아서인듯
# Out:
# 1~100 사이의 정수를 입력하세요: *
# 1~100 사이의 정수가 아닙니다. 다시 입력해주세요
# 1~100 사이의 정수를 입력하세요: *
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-f2b8e2aa8822> in <module>()
#      41           while True:
# ---> 42             inp=int(input('1~100 사이의 정수를 입력하세요: '))
#      43             if inp != answer :                                     #  인풋이 정답과 다른 동안 인풋 받기
#
# ValueError: invalid literal for int() with base 10: '*'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-f2b8e2aa8822> in aaa()
#       6           while True:
# ----> 7             inp=int(input('1~100 사이의 정수를 입력하세요: '))
#       8             if inp != answer :                                     #  인풋이 정답과 다른 동안 인풋 받기
#
# ValueError: invalid literal for int() with base 10: '*'
#
# ...

# %%
#리스트만들어서 브레이크를 두번시켜야함

  #두번째브레이크할 리스트

try:
          import random
          answer = random.randrange(1,101)
          list_1 = []       # 시도 수 카운트를 위한 빈리스트 선언  + 인풋 순서 제출
          while True:     
            inp=int(input('1~100 사이의 정수를 입력하세요: '))     
            if inp != answer :                                     #  인풋이 정답과 다른 동안 인풋 받기
               if   1 <= inp <= 100 :        # 1~100 사이의  
                  if answer > inp :          ## 임의의 정답 값(소스내에 상수로 지정)보다 입력된 숫자가 작으면 "Up" 출력.
                        print("Up")
                        list_1.append(inp)
                  else:              # 1~100 사이의 임의의 정답 값(소스내에 상수로 지정)보다 입력된 숫자가 크면 "Down" 출력.
                        print("Down")
                        list_1.append(inp)  
               else:
                    list_1.append(inp)
                    print('1~100 사이의 정수가 아닙니다. 다시 입력해주세요')
                    
            else:          # 30 정답 맞췄을 때             #인풋이 30이면 프린트
               list_1.append(inp) # 시도 수 카운트
               x = len(list_1)  # 렌으로 원소 수 카운트  -시도 수
               print(f"{x}회째 정답!")
               print('*인풋 순서*')  #1번입력은 2 2번입력은 55 3번입력은 101 4번입력은 30
               for xx in range(x):   # x회째로 반복 
                  if  xx+1 == x :    #끝값은 정답입니다 아닌값은 입니다                                            
                      print(xx+1,'번째 인풋은', list_1[xx],'정답입니다')
                  else:
                      print(xx+1,'번째 인풋은', list_1[xx],'입니다') 
               break
except: 
                 print('1~100 사이의 정수가 아닙니다. 프로그램을 종료합니다')
   

      

#문제점1 인트를 입력하지 않았을 시 list_1.append(inp) 에서 에러가 나고 트라이익셉으로 다시 시도하므로 
   # 정답시도목록으로 카운트되지 않고
# 처음연속두번 인트가 아닌 것을 입력시   에러가 난다  데프로 들어가면 aaa가정의되지않아서인듯
# Out:
# 1~100 사이의 정수를 입력하세요: 5
# Up
# 1~100 사이의 정수를 입력하세요: 60
# Down
# 1~100 사이의 정수를 입력하세요: 30
# Down
# 1~100 사이의 정수를 입력하세요: -
# 1~100 사이의 정수가 아닙니다. 프로그램을 종료합니다

# %%
try:
          import random
          answer = random.randrange(1,101)
          list_1 = []   
          while True:     
            inp=int(input('1~100 사이의 정수를 입력하세요: '))     
            if inp != answer :                                
               if   1 <= inp <= 100 :       
                  if answer > inp :      
                        print("Up")
                        list_1.append(inp)
                  else:             
                        print("Down")
                        list_1.append(inp)  
               else:
                    list_1.append(inp)
                    print('1~100 사이의 정수가 아닌 정수입니다. 다시 입력해주세요')
            else:        
               list_1.append(inp)
               x = len(list_1)
               print(f"{x}회째 정답!")
               print('*인풋 순서*')  
               for xx in range(x): 
                  if  xx+1 == x :                                     
                      print(xx+1,'번째 인풋은', list_1[xx],'정답입니다')
                  else:
                      print(xx+1,'번째 인풋은', list_1[xx],'입니다') 
               break
except: 
                 print('1~100 사이의 정수가 아닙니다. 에러로 프로그램을 종료합니다')
# Out:
# 1~100 사이의 정수를 입력하세요: 5
# Up
# 1~100 사이의 정수를 입력하세요: -
# 1~100 사이의 정수가 아닙니다. 에러로 프로그램을 종료합니다

# %%
 
          import random
          answer = random.randrange(1,101)
          list_1 = []   
          while True:     
           try:   
            inp=int(input('1~100 사이의 정수를 입력하세요: '))     
            if inp != answer :                                
               if   1 <= inp <= 100 :       
                  if answer > inp :      
                        print("Up")
                        list_1.append(inp)
                  else:             
                        print("Down")
                        list_1.append(inp)  
               else:
                    list_1.append(inp)
                    print('1~100 사이의 정수가 아닌 정수입니다. 다시 입력해주세요')
            else:        
               list_1.append(inp)
               x = len(list_1)
               print(f"{x}회째 정답!")
               print('*인풋 순서*')  
               for xx in range(x): 
                  if  xx+1 == x :                                     
                      print(xx+1,'번째 인풋은', list_1[xx],'정답입니다')
                  else:
                      print(xx+1,'번째 인풋은', list_1[xx],'입니다') 
               break
           except:
                print('1~100 사이의 정수가 아닙니다. 에러로 프로그램을 종료합니다')
# Out:
#   File "<ipython-input-37-9f25065aa6a6>", line 2
#     import random
#     ^
# IndentationError: unexpected indent

# %%
import random
answer = random.randrange(1,101)
list_1 = []   
while True:     
           try:   
            inp=int(input('1~100 사이의 정수를 입력하세요: '))     
            if inp != answer :                                
               if   1 <= inp <= 100 :       
                  if answer > inp :      
                        print("Up")
                        list_1.append(inp)
                  else:             
                        print("Down")
                        list_1.append(inp)  
               else:
                    list_1.append(inp)
                    print('1~100 사이의 정수가 아닌 정수입니다. 다시 입력해주세요')
            else:        
               list_1.append(inp)
               x = len(list_1)
               print(f"{x}회째 정답!")
               print('*인풋 순서*')  
               for xx in range(x): 
                  if  xx+1 == x :                                     
                      print(xx+1,'번째 인풋은', list_1[xx],'정답입니다')
                  else:
                      print(xx+1,'번째 인풋은', list_1[xx],'입니다') 
               break
           except:
                print('인트가 아닙니다. 에러로 인풋리스트에 추가되지 않았습니다.')

    
# 문제점 : 인풋이 인트가 아니면 인풋리스트에 추가하지 못함
 ###########################
 ###########################
 ###########################
 ###########################
 ###########################
# Out:
# 1~100 사이의 정수를 입력하세요: 1.1
# 인트가 아닙니다. 에러로 인풋리스트에 추가되지 않았습니다.
# 1~100 사이의 정수를 입력하세요: -1.1
# 인트가 아닙니다. 에러로 인풋리스트에 추가되지 않았습니다.
# 1~100 사이의 정수를 입력하세요: 50
# Down
# 1~100 사이의 정수를 입력하세요: 1,1
# 인트가 아닙니다. 에러로 인풋리스트에 추가되지 않았습니다.
# 1~100 사이의 정수를 입력하세요: 105
# 1~100 사이의 정수가 아닌 정수입니다. 다시 입력해주세요
# 1~100 사이의 정수를 입력하세요: -1
# 1~100 사이의 정수가 아닌 정수입니다. 다시 입력해주세요
# 1~100 사이의 정수를 입력하세요: 40
# Down
# 1~100 사이의 정수를 입력하세요: 30
# Down
# 1~100 사이의 정수를 입력하세요: 20
# Up
# 1~100 사이의 정수를 입력하세요: 25
# Up
# 1~100 사이의 정수를 입력하세요: 27
# Up
# 1~100 사이의 정수를 입력하세요: 28
# Up
# 1~100 사이의 정수를 입력하세요: 29
# 10회째 정답!
# *인풋 순서*
# 1 번째 인풋은 50 입니다
# 2 번째 인풋은 105 입니다
# 3 번째 인풋은 -1 입니다
# 4 번째 인풋은 40 입니다
# 5 번째 인풋은 30 입니다
# 6 번째 인풋은 20 입니다
# 7 번째 인풋은 25 입니다
# 8 번째 인풋은 27 입니다
# 9 번째 인풋은 28 입니다
# 10 번째 인풋은 29 정답입니다

# %%
import random
answer = random.randrange(1,101)
list_1 = []   
while True:     
     try:   
            inp=int(input('1~100 사이의 정수를 입력하세요: '))     
            if inp != answer :                                
               if   1 <= inp <= 100 :       
                  if answer > inp :      
                        print("Up")
                        list_1.append(inp)
                  else:             
                        print("Down")
                        list_1.append(inp)  
               else:
                    list_1.append(inp)
                    print('1~100 사이의 정수가 아닌 정수입니다. 다시 입력해주세요')
            else:        
               list_1.append(inp)
               x = len(list_1)
               print(f"{x}회째 정답!")
               print('*인풋 순서*')  
               for xx in range(x): 
                  if  xx+1 == x :                                     
                      print(xx+1,'번째 인풋은', list_1[xx],'정답입니다')
                  else:
                      print(xx+1,'번째 인풋은', list_1[xx],'입니다') 
               break
     except:
                print('인트가 아닙니다. 에러로 인풋리스트에 추가되지 않았습니다.')
                
# 문제점 : 1. 인풋이 인트가 아니면 인풋리스트에 추가하지 못함
# Out:
# Up
# Up
# Down
# Down
# Down
# Up
# Up
# 8회째 정답!
# *인풋 순서*
# 1 번째 인풋은 50 입니다
# 2 번째 인풋은 40 입니다
# 3 번째 인풋은 70 입니다
# 4 번째 인풋은 60 입니다
# 5 번째 인풋은 65 입니다
# 6 번째 인풋은 45 입니다
# 7 번째 인풋은 55 입니다
# 8 번째 인풋은 57 정답입니다
# 인트가 아닙니다. 에러로 인풋리스트에 추가되지 않았습니다.
# 인트가 아닙니다. 에러로 인풋리스트에 추가되지 않았습니다.
# 인트가 아닙니다. 에러로 인풋리스트에 추가되지 않았습니다.
# 인트가 아닙니다. 에러로 인풋리스트에 추가되지 않았습니다.
# 인트가 아닙니다. 에러로 인풋리스트에 추가되지 않았습니다.
# 인트가 아닙니다. 에러로 인풋리스트에 추가되지 않았습니다.
# 인트가 아닙니다. 에러로 인풋리스트에 추가되지 않았습니다.

# %%
######################## 모든에러처리

import random
answer = random.randrange(1,101)
list_1 = []   
while True:     
     try:                      
            inp=input('1이상 100이하의 정수를 입력하세요: ')     
            if int(inp) != answer :                                
               if   1 <= int(inp) <= 100 :       
                  if answer > int(inp) :      
                        print("Up")
                        list_1.append(inp)
                  else:             
                        print("Down")
                        list_1.append(inp)  
               else:
                    list_1.append(inp)
                    print('지정범위를 벗어난 정수입니다. 1이상 100이하의 정수를 입력하세요')
            else:        
               list_1.append(inp)
               x = len(list_1)
               print(f"{x}회째 정답!")
               print('*인풋 순서*')  
               for xx in range(x): 
                  if  xx+1 == x :                                     
                      print(xx+1,'번째 인풋은', list_1[xx],'정답입니다')
                  else:
                      print(xx+1,'번째 인풋은', list_1[xx],'입니다') 
               break
     except:
                print('정수가 아닙니다. 1이상 100이하의 정수를 입력하세요')
                list_1.append(inp)
                        
##########################
