# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pandas import DataFrame
from pandas import Series

# %%
벡터 1차원  한방향으로나열
벡터: 방향성을 가진 데이터
     축 하나인 데이터

행렬 matrix : 축이 2개
 차원이늘어나면 축이 늘어난다

머신러닝이 뭐야
   y=wx+b 데이터를 주면 컴퓨터 스스로 함수/공식 을 만들어 내는 것  x,y 를 주면 w와 b를 컴퓨터가 알아내는 것이다

dot()  내적(행렬식 곱셈) numpy.dot(a,b)

# %%
브로드캐스팅 연산
    축이 어레이 하나당 0~1개 늘어나야 할 때 가능  

쉐입
리쉐입 : 원래 어레이의 원소의 수를 고려해야 한다  (행,열)   -1은 나머지 전부
    행*열 을 곱해서 원래 어레이의 원소의 수와 동일해야 한다
        행과 열의 곱 = 원소수  가 int 정수로 떨어져야 한다 

 (행,열)  > 2차원
 ( , , )>3차원

논리연산
    원소별로 동작

    값이 바뀌는 것이 아닌 생성

# %%
올 과 에니 함수

엔피.all(조건)  조건이   모두참이어야 참
     any                하나만참이라도 참

# %%
np.random.randint(0,101,1000)  #영부터백까지 천개의 랜덤 수

# %%
x = np.array([1,2,3,4,5])
np.where(x==3)
# Out:
# (array([2]),)

# %%
x = np.array([1,2,3,4,5])
np.where(x==3,1,2)
# Out:
# array([2, 2, 1, 2, 2])

# %%
argsort 오름차순 순번알려줌
[argsort] 로 오름차순으로 정렬이 가능

# %%
판다스선언

임폴 넘파이 에스 엔피
임폴 판다스 에스 피디
프롬판다스 임폴 시리즈,데이터프레임

# %%
시리즈(각 열)
시리즈가 모인 것  데이터프레임     데이터전체 테이블형태

# %%
DataFrame()
df=  pd.read_csv('파일진짜이름경로')

# %%
loc [ 인덱,'시리즈']
iloc [ 인덱,시리즈인덱]

# %%
데이터 빼기   drop 함수
ㅇㅇ = ㅁㅁ.drop(colums=['시리즈명'])

# %%
.그룹바이(기준시리즈)(적용열시리즈),  섬/민/카운트

2

# %%
데이터프레임 3개는 동시에 병합 불가
2개를 병합한 다음 나머지 하나를 병함

디폴트 axis=0 행방향병합 (세로로합치기)
            1 열방향
    

원본수정하려면 inplace=True 나     변수= 으로 바로 대입
               두가지를 동시에 쓰지 못한다
(리턴값이없어서)

# %%
import matplotlib.pylot as plt


볼 때
plt.show()
# Out:
#   File "<ipython-input-98-bbbe11c441f9>", line 4
#     볼 때
#       ^
# SyntaxError: invalid syntax

# %%
from matplotlib import lines
import matplotlib.pyplot as plt
X=range(100)  #백개 원소
Y=[i for i in X]    # 0.0에서 100,100  좌표
Y1=[i+100 for i in X]  

plt.plot(Y,color='b',linestyle='dashed')
plt.plot(Y1,color='r',ls='dotted')

plt.title('g_test')
plt.show()

# %%
fig = plt.figure()
fig.set_size_inches(10,10) # 판의 크기
ax_1=fig.add_subplot(1,2,1)
ax_2=fig.add_subplot(1,2,2)
ax_1.plot(Y,c='r')
ax_1.set_title('f_1')
ax_2.plot(Y1,c='g')
ax_2.set_title('f_2')
plt.show()

# %%
plt.plot(Y,c='r', ls = 'dotted', label = 'y_data')  #ls 라인스타일
plt.plot(Y1,c='g', ls = 'dashed', label = 'y1_data') 
#plt.legend(shadow=True)
plt.legend(loc='upper right', fancybox=False, shadow=True)
plt.title('y=wx+b')
plt.xlabel('x_data')

plt.ylabel('y_ck')
plt.show()

# %%
plt.plot(Y,c='r', ls = 'dotted',marker='x', label = 'y_data')  #ls 라인스타일
plt.plot(Y1,c='g', ls = 'dashed', label = 'y1_data') 
#plt.legend(shadow=True)
plt.legend(loc='upper right', fancybox=False, shadow=True)
plt.title('y=wx+b')
plt.xlabel('x_data')

plt.ylabel('y_ck')
plt.show()

# %%
plt.plot(Y,'bx', label = 'y_data')  #ls 라인스타일
plt.plot(Y1,'bx', label = 'y1_data') 
#plt.legend(shadow=True)
plt.legend(loc='upper right', fancybox=False, shadow=True)
plt.title('y=wx+b')
plt.xlabel('x_data')

plt.ylabel('y_ck')
plt.show()

# %%
import numpy as np
data = np.random.rand(512,2) # 512행 2열
data.shape
# Out:
# (512, 2)

# %%
import numpy as np
data1 = np.random.rand(512,2) # 512행 2열
data2 = np.random.rand(512,2) # 512행 2열
plt.scatter(data1[:,0],data1[:,1], c='b', marker = 'x')    # :  전부에서   0부터 1까지 뽑기   plt.scatter(data2[:,0],data2[:,1],
# c='r', marker = 'o')

# %%
import numpy as np
data1 = np.random.rand(512,2) # 512행 2열
data2 = np.random.rand(512,2) # 512행 2열               plot 선그래프 스캐터는 점그래프
plt.plot(data1[:,0],data1[:,1], 'bx')     (엑스,와이 값)
plt.plot(data2[:,0],data2[:,1], c='r', marker = 'o')#
# Out:
#   File "<ipython-input-100-9b306b9ea9cc>", line 4
#     plt.plot(data1[:,0],data1[:,1], 'bx')     (엑스,와이 값)
#                                                      ^
# SyntaxError: invalid syntax

# %%
#np.random.rand(10)  #원소10개

import numpy as np

n=50
x=np.random.rand(n)
y=np.random.rand(n)
c = np.random.rand(n)
#원넓이
ar= np.pi * (15*np.random.rand(n))**2       #파이 원주율      / 파이알제곱
plt.scatter(x,y, c='b', s = ar)  #원넓이수정분포도

# %%
#np.random.rand(10)  #원소10개

import numpy as np

n=50
x=np.random.rand(n)
y=np.random.rand(n)
c = np.random.rand(n)
#원넓이
ar= np.pi * (15*np.random.rand(n))**2       #파이 원주율      / 파이알제곱
plt.scatter(x,y, c=c, s = ar, alpha=0.5)  #알파 투명도

# %%
data=[[5,25,50,20],[4,23,51,17],[6,22,52,19]]
X=np.arange(0,8,2) #영에서팔까지 2스텝

plt.bar(X,data[0] , width=0.4 , color='b')
plt.bar(X+0.5,data[1]  , width=0.4, color='r')
plt.bar(X+1,data[2]  , width=0.4, color='g')
plt.xticks(X+0.5,('A','B','C','D'))

plt.show()

# %%
data=np.array([[5,25,50,20],[4,23,51,17],[6,22,52,19]])
X=np.arange(0,8,2) #영에서팔까지 2스텝

c_l=['r','g','b']
data_l=['A','B','C']
X=np.arange(data.shape[1])
data=np.array([[5,5,5,5],
               [4,23,51,17],
               [6,22,52,19]])

# %%
for i in range(3):
    plt.bar() #bar막대그래프 plot 선그래프 scatter 점그래프
    plt.show() #는초기화의역할도한다 즉 그래프는 3개가 아닌 1개가 뜬다 3개가 쌓인 정보
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-142-03caae69cc25> in <module>()
#       1 for i in range(3):
# ----> 2     plt.bar() #bar막대그래프 plot 선그래프 scatter 점그래프
#       3     plt.show() #는초기화의역할도한다 즉 그래프는 3개가 아닌 1개가 뜬다 3개가 쌓인 정보
#       4
#
# TypeError: bar() missing 2 required positional arguments: 'x' and 'height'

# %%
for i in range(3):
    plt.bar(X,data[i]) #bar막대그래프 plot 선그래프 scatter 점그래프
    plt.show() #

# %%
for i in range(3):
    plt.bar(X,data[i],bottom=np.sum(data[:i],axis=0), color=c_l[i] ,label=data_l[i]) #bar막대그래프 plot 선그래프 scatter 점그래프
plt.legend()
plt.show()

# %%
n=1000
x=np.random.normal(size=n) #노말 평균요소를분포요소로
plt.hist(x,bins=100)
# Out:
# (array([ 1.,  1.,  1.,  0.,  0.,  1.,  1.,  0.,  2.,  0.,  1.,  1.,  1.,
#          2.,  2.,  2.,  2.,  1.,  4.,  6.,  1.,  5., 10.,  5., 13.,  9.,
#         11., 10.,  6., 14., 22., 17., 12., 16., 18., 11., 24., 30., 17.,
#         22., 10., 21., 25., 22., 19., 30., 22., 21., 27., 20., 31., 26.,
#         25., 28., 19., 20., 21., 20., 19., 23., 18., 21., 20., 12., 16.,
#         14., 14., 13., 14.,  7.,  8.,  9., 11.,  7.,  8.,  4.,  8.,  9.,
#          5.,  4.,  2.,  2.,  0.,  3.,  2.,  5.,  3.,  1.,  3.,  0.,  0.,
#          1.,  0.,  0.,  0.,  3.,  0.,  0.,  1.,  1.]),
#  array([-2.94635962, -2.88609676, -2.82583391, -2.76557105, -2.7053082 ,
#         -2.64504534, -2.58478249, -2.52451963, -2.46425678, -2.40399392,
#         -2.34373107, -2.28346821, -2.22320536, -2.1629425 , -2.10267965,
#         -2.04241679, -1.98215394, -1.92189108, -1.86162823, -1.80136537,
#         -1.74110252, -1.68083966, -1.62057681, -1.56031395, -1.5000511 ,
# ...

# %%
data=np.random.rand(100,5)  #랜드(행,열)  만들기

data
# Out:
# array([[1.18836974e-01, 8.48593140e-01, 5.67148640e-01, 5.93028023e-01,
#         5.96264882e-02],
#        [3.62136478e-01, 7.68217187e-01, 7.50013719e-01, 5.76292744e-01,
#         5.91998501e-01],
#        [6.25111852e-01, 1.96410353e-01, 1.97056346e-01, 4.75849779e-01,
#         4.34574853e-01],
#        [2.42391010e-01, 1.71052303e-01, 6.92926993e-01, 1.19204273e-01,
#         9.84892684e-02],
#        [7.62104114e-01, 9.31426290e-01, 8.61827475e-03, 2.87019496e-01,
#         3.66484166e-01],
#        [6.22512545e-01, 5.47985279e-01, 4.16847827e-01, 6.07216556e-01,
#         9.17612219e-01],
#        [6.66242125e-01, 7.63494751e-01, 2.19081357e-01, 8.19954023e-01,
#         8.95356659e-01],
#        [7.39326459e-01, 4.20962611e-01, 7.34471280e-02, 1.20114005e-01,
#         5.61982276e-01],
#        [4.40800351e-01, 7.51382482e-01, 6.29425677e-01, 7.82362826e-01,
#         1.69399301e-01],
#        [5.63069771e-01, 3.68627290e-01, 7.45710042e-01, 8.59875566e-01,
# ...

# %%
data=np.random.randn(100,5)  #랜드(행,열)  만들기

data
# Out:
# array([[-1.04994867, -0.53059852,  0.74001798, -0.04615696,  0.25969193],
#        [-1.00977133, -1.42614647,  0.29539486,  0.26958137, -0.1645283 ]])

# %%
plt.boxplot(data)
plt.show()

# %%
범레
축객체마다범레를설정할수잇음
레전드함수사용하여생성
    샤도우매개변수로범레에그림자효과추가

산점도 그래프
    데이터분포를이차원평면에표현
    매개변수시는포인트색상을지정
    마커는포인트모양을지정
    사이즈는포인트크기를지정

막대그래프
누적마대그래프
히스토그램
    데이터의분포를표현

상자그림 박스플롯
    사분위수를 시각화하여 데이터의분포화 밀집 정도를 표현

# %%
시본 seaborn
맷플롯립을 바탕으로 다양한 함수 사용을 돕는 일종의 래퍼모듈
맷플롯립과 동일한 결과물이 나오며 작성과정이 간단
    그림객체나 축 객체 같은 복잡한 개념이 없음
    xticks 설정하지 않아도 각 축에 레벨 자동으로 생성
    데이터프레임과 엑스,와이 에 해당하는 열 이름만 지정하면 됨

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

fmri = sns.load_dataset('fmri')
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

fmri = sns.load_dataset('fmri')
sns.lineplot(x='timepoint',y='signal',data=fmri)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

fmri = sns.load_dataset('fmri')
fmri.sample(n=10,random_state=1)
# Out:
#     subject  timepoint event    region    signal
# 806      s6         18   cue  parietal  0.019532
# 691      s5         15   cue   frontal -0.019507
# 148      s5          8  stim  parietal  0.006805
# 676     s13          0   cue  parietal -0.018394
# 156     s11          7  stim  parietal  0.254042
# 27       s1         17  stim  parietal -0.038021
# 200     s11          4  stim  parietal  0.087175
# 262      s3          0  stim  parietal -0.008576
# 94       s4         12  stim  parietal -0.090036
# 339      s4          5  stim   frontal  0.455575

# %%
sns.lineplot(x='timepoint',y='signal',hue='event',data=fmri)
# hue='event' 이벤트를 기준으로

# %%
tips=sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.regplot(x='total_bill',y='tip', data=tips)                    #reglot 회귀플랏 리그레이션플랏

# %%
sns.scatterplot(x='total_bill',y='tip',hue='time', data=tips)       #산점도그래프

# %%
sns.countplot(x='smoker', data=tips)

# %%
sns.countplot(x='smoker',hue='time', data=tips)

# %%
sns.barplot(x='day',y='total_bill', data=tips)

# %%
시본

회귀그래프
    회귀식을적용하여선형회귀추세선을그래프에함께작성
    선형회귀추세선 데이터를 기반으로데이터의엑스값

막대그래프
    와이값이연속형값일경우해당값들의평균을나타냄
    데이터의신뢰구간을검은색막대로표현
    함수바플롯사용

사전정의된그래프
    맥플롯립 관점에서 여러그래프들을합쳐정보를추출
    특히범주형데이터에유용

분포를나타내는그래프
    바이올린플롯과스웜플롯


바이올린플롯
    상자그림과분포도를한번에나타낼수잇음
    엑스축에는범주형데이터와이축에는연속형데이터

스웜플롯
    바이올린프롯과같은형태에산점도로데이터분포를나타냄
    매개변수휴로두개이상의범주형데이터를점이겹치지않게정리
    영역별데이터양을직관적으로보여줌

# %%
sns.violinplot(x='day',y='total_bill',data=tips, hue='smoker')

# %%
sns.swarmplot(x='day',y='total_bill',data=tips, hue='smoker')

# %%
sns.FacetGrid(tips,col='time', row='sex') #축만 설정

# %%
g=sns.FacetGrid(tips,col='time', row='sex')
#map 입력함수를 이용해서 값을 각각 넣어주는 함수

#map(입력함수,데이터구조)
g.map(sns.scatterplot, 'total_bill','tip')
#                        x축      , 와이축

# %%
g=sns.FacetGrid(tips,col='time', row='sex')
#map 입력함수를 이용해서 값을 각각 넣어주는 함수

#map(입력함수,데이터구조)
g.map(sns.histplot, 'total_bill')
#

# %%
g=sns.FacetGrid(tips,col='time', row='sex')
#map 입력함수를 이용해서 값을 각각 넣어주는 함수

#map(입력함수,데이터구조)
g.map_dataframe(sns.histplot, x='total_bill')
#
